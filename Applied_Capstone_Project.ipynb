# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import folium
from geopy.geocoders import Nominatim 
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ###### In this Jupyter Notebook, we will illsutrate venues(Gym/Fitness) and the local sports shops in 4 different cities across China: Beijing, Shanghai, Chengdu, Chongqing

# %%
#Define Foursquare API (free trial account)
CLIENT_ID = 'P1X3FJMKPO4DWCK1FDOBLB51PF4QPP4C1OQIQENXUREVCXJX'
CLIENT_SECRET = 'VD1ZTKQQOOKTIONJ5TGCOVXFDK25YYOBOINQ13J0NET0YGX0'
VERSION = '20200727'

# %% [markdown]
# ###### First, lets get the [Lat, Lon] coordinates of these cities so we can generate a map via Folium

# %%
geolocator_Beijing = Nominatim(user_agent = 'TayTay')
city_1 = 'Beijing'
country = 'China'
location_Beijing = geolocator_Beijing.geocode(city_1 + ',' + country)
print(location_Beijing.address)
print(location_Beijing.latitude, location_Beijing.longitude)
# Out:
# 北京市, 东城区, 北京市, 100010, China 中国
# 39.906217 116.3912757

# %%
geolocator_Shanghai = Nominatim(user_agent = 'TayTay')
city_2 = 'Shanghai'
country = 'China'
location_Shanghai = geolocator_Shanghai.geocode(city_2 + ',' + country)
print(location_Shanghai.address)
print(location_Shanghai.latitude, location_Shanghai.longitude)
# Out:
# 上海市, 黄浦区, 上海市, 200010, China 中国
# 31.2252985 121.4890497

# %%
geolocator_Chengdu = Nominatim(user_agent = 'TayTay')
city_3 = 'Chengdu'
country = 'China'
location_Chengdu = geolocator_Chengdu.geocode(city_3 + ',' + country)
print(location_Chengdu.address)
print(location_Chengdu.latitude, location_Chengdu.longitude)
# Out:
# 成都市, 四川省, China 中国
# 30.6624205 104.0633219

# %%
geolocator_Chongqing = Nominatim(user_agent = 'TayTay')
city_4 = 'Chongqing'
country = 'China'
location_Chongqing = geolocator_Chongqing.geocode(city_4 + ',' + country)
print(location_Chongqing.address)
print(location_Chongqing.latitude, location_Chongqing.longitude)
# Out:
# 重庆市, 渝中区 (Yuzhong), 重庆市中心, 重庆市, 400014, China 中国
# 29.5585712 106.5492822

# %% [markdown]
# ###### For map display, we will use Folium, and we round the latitude and longitude of cities to 2 decimal places for convience

# %%
#round coordinates into 2 decimal places
latitude_0 = location_Beijing.latitude
longitude_0 = location_Beijing.longitude
longitude_0_0 = round(longitude_0,2)
latitude_0_0 = round(latitude_0,2)

latitude_1 = location_Shanghai.latitude
longitude_1 = location_Shanghai.longitude
longitude_1_1 = round(longitude_1,2)
latitude_1_1 = round(latitude_1,2)

latitude_2 = location_Chengdu.latitude
longitude_2 = location_Chengdu.longitude
longitude_2_2 = round(longitude_2,2)
latitude_2_2 = round(latitude_2,2)

latitude_3 = location_Chongqing.latitude
longitude_3 = location_Chongqing.longitude
longitude_3_3 = round(longitude_3,2)
latitude_3_3 = round(latitude_3,2)

# %% [markdown]
# ###### For map display Folium is used, as Folium does not have a language parameter, if have doubt regards to city coordinate, please feel free to check the [lat, lon] coordinates on a map of your choice. Google, Baidu, Gaode ect.

# %%
#display maps
map_Beijing = folium.Map(location=[latitude_0_0, longitude_0_0], zoom_start=10)
map_Beijing
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_Shanghai = folium.Map(location=[latitude_1_1, longitude_1_1], zoom_start=11)
map_Shanghai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_Chengdu = folium.Map(location=[latitude_2_2, longitude_2_2], zoom_start=11)
map_Chengdu
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_Chongqing = folium.Map(location=[latitude_2_2, longitude_2_2], zoom_start=11)
map_Chongqing
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Now we use the foursquare API to search for venues(gym/fitness) in each city

# %%
import requests

LIMIT = 1000
cities = ['Beijing,Beijing', 'Shanghai, Shanghai', 'Chengdu, Sichuan', 'Chongqing, Chongqing']
results_gym = {}
for city in cities:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        city,
        LIMIT,
        "4bf58dd8d48988d175941735") # Gym/Fitness PLACE CATEGORY ID
    results_gym[city] = requests.get(url).json()

# %%
#Search results for local gym/fitness venue in Beijing
results_gym[cities[0]]
# Out:
# {'meta': {'code': 200, 'requestId': '5f23edcf72cee757fc986bdb'},
#  'response': {'geocode': {'cc': 'CN',
#    'center': {'lat': 39.9075, 'lng': 116.39723},
#    'displayString': 'Beijing, Beijing Shi, China',
#    'geometry': {'bounds': {'ne': {'lat': 41.05875499151405,
#       'lng': 117.49936797940963},
#      'sw': {'lat': 39.44236100189344, 'lng': 115.41642409091048}}},
#    'longId': '72057594039744606',
#    'slug': 'beijing',
#    'what': '',
#    'where': 'beijing beijing'},
#   'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc97941937ca59323e3a592-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4bc97941937ca59323e3a592',
#        'location': {'address': '2A Gongtibei Rd.',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['2A Gongtibei Rd.', '北京市', '北京市, 100027', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.93068253523401,
#           'lng': 116.45293789829486}],
#         'lat': 39.93068253523401,
#         'lng': 116.45293789829486,
#         'postalCode': '100027',
#         'state': '北京市'},
#        'name': 'Pacific Century Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53cb3c04498e9b1d665813da-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '53cb3c04498e9b1d665813da',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.9303951581806,
#           'lng': 116.44720795450174}],
#         'lat': 39.9303951581806,
#         'lng': 116.44720795450174},
#        'name': 'B Active Sanlitun SOHO',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f854e85e4b04578ff6496ab-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4f854e85e4b04578ff6496ab',
#        'location': {'address': 'Futong West Street',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['Futong West Street', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.9970543164366,
#           'lng': 116.47480940137537}],
#         'lat': 39.9970543164366,
#         'lng': 116.47480940137537,
#         'state': '北京市'},
#        'name': 'D-Space 东田运动',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fcca1a7e4b00d5bd598bbc3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4fcca1a7e4b00d5bd598bbc3',
#        'location': {'address': 'East Ave Apt B1 | 幸福三村3楼B1',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'Dongzhimenwai Dajie | 东直门外大街',
#         'formattedAddress': ['East Ave Apt B1 | 幸福三村3楼B1 (Dongzhimenwai Dajie | 东直门外大街)',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.93683202941104,
#           'lng': 116.44509021346761}],
#         'lat': 39.93683202941104,
#         'lng': 116.44509021346761,
#         'state': '北京市'},
#        'name': 'CSI Bally Fitness (CSI Bally Fitness 中体倍力健身)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-556fe5c9498ef85b113d4075-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '556fe5c9498ef85b113d4075',
#        'location': {'address': 'Shoucheng International',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'Guang qu Road',
#         'formattedAddress': ['Shoucheng International (Guang qu Road)',
#          '北京市',
#          '北京市, 100022',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.890489666333835,
#           'lng': 116.46264689858641}],
#         'lat': 39.890489666333835,
#         'lng': 116.46264689858641,
#         'postalCode': '100022',
#         'state': '北京市'},
#        'name': 'Young Fit Health Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4db0e0ee5da32cf2df51ecb7-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4db0e0ee5da32cf2df51ecb7',
#        'location': {'address': '西城区复兴门内大街101号百盛购物中心2号楼10楼',
#         'cc': 'CN',
#         'city': '西城区',
#         'country': '中国',
#         'formattedAddress': ['西城区复兴门内大街101号百盛购物中心2号楼10楼', '西城区', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.906550339831696,
#           'lng': 116.35583689697737}],
#         'lat': 39.906550339831696,
#         'lng': 116.35583689697737,
#         'state': '北京市'},
#        'name': '青鸟健身(百盛店)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52136665498e19f6f439f26b-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '52136665498e19f6f439f26b',
#        'location': {'address': 'Tower 2, 25 Yuanda Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'at Aloft Beijing Haidian',
#         'formattedAddress': ['Tower 2, 25 Yuanda Rd (at Aloft Beijing Haidian)',
#          '北京市',
#          '北京市, 100097',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.957065,
#           'lng': 116.273063}],
#         'lat': 39.957065,
#         'lng': 116.273063,
#         'postalCode': '100097',
#         'state': '北京市'},
#        'name': 'Aloft Recharge',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a561471cf72a07616106f24-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5a561471cf72a07616106f24',
#        'location': {'address': '华贸购物中心4层',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': '朝阳区建国路77号',
#         'formattedAddress': ['华贸购物中心4层 (朝阳区建国路77号)',
#          '北京市',
#          '北京市, 100000',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.90796171492077,
#           'lng': 116.47541629996932}],
#         'lat': 39.90796171492077,
#         'lng': 116.47541629996932,
#         'postalCode': '100000',
#         'state': '北京市'},
#        'name': 'Keepland 华贸店',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e6b834fae60950955f34916-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4e6b834fae60950955f34916',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.956521,
#           'lng': 116.45389}],
#         'lat': 39.956521,
#         'lng': 116.45389},
#        'name': 'Oak Chateau じむ',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5c3430d2cad1b6002c95e043-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5c3430d2cad1b6002c95e043',
#        'location': {'address': '财富购物中心 2F',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': '兆丰街',
#         'formattedAddress': ['财富购物中心 2F (兆丰街)', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.916225433691096,
#           'lng': 116.45376187350517}],
#         'lat': 39.916225433691096,
#         'lng': 116.45376187350517,
#         'state': '北京市'},
#        'name': 'Keepland Fortune Plaza 财富购物中心店',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eca35db722e1437997fad5f-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4eca35db722e1437997fad5f',
#        'location': {'address': '天之骄子',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['天之骄子', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.893725195289626,
#           'lng': 116.45894229253297}],
#         'lat': 39.893725195289626,
#         'lng': 116.45894229253297,
#         'state': '北京市'},
#        'name': 'Joy sunny Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd830f45cf276b015a19c00-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4bd830f45cf276b015a19c00',
#        'location': {'address': 'East 3rd Ring M Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['East 3rd Ring M Rd', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.903672,
#           'lng': 116.445867}],
#         'lat': 39.903672,
#         'lng': 116.445867,
#         'state': '北京市'},
#        'name': 'Soho健身俱乐部',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf72a594a67c9288b3623cf-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4bf72a594a67c9288b3623cf',
#        'location': {'address': '朝阳区住邦2000',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['朝阳区住邦2000', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91415693660267,
#           'lng': 116.48882974320617}],
#         'lat': 39.91415693660267,
#         'lng': 116.48882974320617,
#         'state': '北京市'},
#        'name': 'Ozone',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a5ca43e75a6ea1a41f5d258-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5a5ca43e75a6ea1a41f5d258',
#        'location': {'address': 'No.1 Jianguomenwai Avenue',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['No.1 Jianguomenwai Avenue',
#          '北京市',
#          '北京市, 100004',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.911660603827116,
#           'lng': 116.45461168718775}],
#         'lat': 39.911660603827116,
#         'lng': 116.45461168718775,
#         'postalCode': '100004',
#         'state': '北京市'},
#        'name': 'Trainyard',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5393c866498ea18b1c944877-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5393c866498ea18b1c944877',
#        'location': {'address': '21 Jianguomen Outer Ave',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['21 Jianguomen Outer Ave',
#          '北京市',
#          '北京市, 100020',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.90937000002919,
#           'lng': 116.43340212217994}],
#         'lat': 39.90937000002919,
#         'lng': 116.43340212217994,
#         'postalCode': '100020',
#         'state': '北京市'},
#        'name': 'The St. Regis Athletic Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f02569f2c5b66f33e96275d-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4f02569f2c5b66f33e96275d',
#        'location': {'address': 'Beijing Capital Airport Terminal 3',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['Beijing Capital Airport Terminal 3',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.047796401009926,
#           'lng': 116.61353517128201}],
#         'lat': 40.047796401009926,
#         'lng': 116.61353517128201,
#         'state': '北京市'},
#        'name': 'Gym & Spa @ Hilton Beijing Capital Airport',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fc6a84ce4b058a77a8609d1-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4fc6a84ce4b058a77a8609d1',
#        'location': {'address': 'Holiday Inn Beijing Haibian',
#         'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['Holiday Inn Beijing Haibian', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.00170665316662,
#           'lng': 116.33297595776277}],
#         'lat': 40.00170665316662,
#         'lng': 116.33297595776277},
#        'name': 'Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-520903ff11d247f8468f307d-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '520903ff11d247f8468f307d',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.94863071467538,
#           'lng': 116.4547983134473}],
#         'lat': 39.94863071467538,
#         'lng': 116.4547983134473},
#        'name': 'Westin WORKOUT Fitness Studio',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bfb87a2c8b2fb002cbb55f0-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5bfb87a2c8b2fb002cbb55f0',
#        'location': {'address': '达美中心T1五层',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': '青年路8号院',
#         'formattedAddress': ['达美中心T1五层 (青年路8号院)', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.9364624072986,
#           'lng': 116.50987023597465}],
#         'lat': 39.9364624072986,
#         'lng': 116.50987023597465,
#         'state': '北京市'},
#        'name': 'Infinity Fitness Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57981b23498e4da6aa107056-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '57981b23498e4da6aa107056',
#        'location': {'address': 'No.37, N. 3rd Ring Road East，Floor 8',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['No.37, N. 3rd Ring Road East，Floor 8',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.9677482523447,
#           'lng': 116.40372663559751}],
#         'lat': 39.9677482523447,
#         'lng': 116.40372663559751,
#         'state': '北京市'},
#        'name': 'The Sun Personal Training',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-590ee3f50f013c66ce825edb-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '590ee3f50f013c66ce825edb',
#        'location': {'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91918112404122,
#           'lng': 116.44790135046038}],
#         'lat': 39.91918112404122,
#         'lng': 116.44790135046038,
#         'state': '北京市'},
#        'name': 'SUPERMONKEY 全能店',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4baf13a9f964a52010ea3be3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '4baf13a9f964a52010ea3be3',
#        'location': {'address': '6/F, 17 Gongti Beilu 工体北路17号工人体育场北门对面 6层',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': "Opp. N gate of Worker's Stadium, above Bodhi",
#         'formattedAddress': ["6/F, 17 Gongti Beilu 工体北路17号工人体育场北门对面 6层 (Opp. N gate of Worker's Stadium, above Bodhi)",
#          '北京市',
#          '北京市, 100010',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.932674965378354,
#           'lng': 116.44037131249215}],
#         'lat': 39.932674965378354,
#         'lng': 116.44037131249215,
#         'postalCode': '100010',
#         'state': '北京市'},
#        'name': 'Yoga Yard (瑜伽苑)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ee83c42b8f756f1d0d82ba2-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4ee83c42b8f756f1d0d82ba2',
#        'location': {'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.94546326934315,
#           'lng': 116.45217718407876}],
#         'lat': 39.94546326934315,
#         'lng': 116.45217718407876,
#         'state': '北京市'},
#        'name': 'Westin Workout',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-519a54e8498e7356803ab544-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '519a54e8498e7356803ab544',
#        'location': {'address': 'Sunshine 100 Basement',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['Sunshine 100 Basement', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91187529399628,
#           'lng': 116.46915297189368}],
#         'lat': 39.91187529399628,
#         'lng': 116.46915297189368,
#         'state': '北京市'},
#        'name': 'Dongting Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c2c513b17a29c7431b8e212-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4c2c513b17a29c7431b8e212',
#        'location': {'address': '工体北路2号兆龙饭店西楼',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['工体北路2号兆龙饭店西楼', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.9323048731472,
#           'lng': 116.4537339475771}],
#         'lat': 39.9323048731472,
#         'lng': 116.4537339475771,
#         'state': '北京市'},
#        'name': 'Nirvana Fitness 青鸟健身',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5631a634498e8cced53bc7bc-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '5631a634498e8cced53bc7bc',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.99992827875302,
#           'lng': 116.48029086218327}],
#         'lat': 39.99992827875302,
#         'lng': 116.48029086218327},
#        'name': '锤子科技健身房',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50ab6c56e4b035aaf41a6ff1-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '50ab6c56e4b035aaf41a6ff1',
#        'location': {'address': '太阳宫一街1号院（太阳公元）8号楼',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'Xibahe Rd.',
#         'formattedAddress': ['太阳宫一街1号院（太阳公元）8号楼 (Xibahe Rd.)',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.980181584337124,
#           'lng': 116.43619139135377}],
#         'lat': 39.980181584337124,
#         'lng': 116.43619139135377,
#         'state': '北京市'},
#        'name': 'Ozone Fitness 太阳公元',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e59e34fb993732579f021ee-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4e59e34fb993732579f021ee',
#        'location': {'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.93625055348196,
#           'lng': 116.44855252691741}],
#         'lat': 39.93625055348196,
#         'lng': 116.44855252691741,
#         'state': '北京市'},
#        'name': 'Fitness Center @OppositebHouse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-596087172f97ec37ca518b85-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '596087172f97ec37ca518b85',
#        'location': {'address': '工体北门一层23号看台',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['工体北门一层23号看台', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.930911652682816,
#           'lng': 116.44056540596196}],
#         'lat': 39.930911652682816,
#         'lng': 116.44056540596196,
#         'state': '北京市'},
#        'name': 'SuperMonkey 超级猩猩健身舱（工体店）',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e9582672c5b42ad93c1d690-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4e9582672c5b42ad93c1d690',
#        'location': {'address': '3/F Tower 26 Central Park',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['3/F Tower 26 Central Park', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91653739910263,
#           'lng': 116.44945725580972}],
#         'lat': 39.91653739910263,
#         'lng': 116.44945725580972,
#         'state': '北京市'},
#        'name': 'Fitness Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d7dcf19dd4a6ea8633e5e25-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4d7dcf19dd4a6ea8633e5e25',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.00007938440984,
#           'lng': 116.34777747162916}],
#         'lat': 40.00007938440984,
#         'lng': 116.34777747162916},
#        'name': 'ZhangBei Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57e1c788cd100d45be001cc0-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '57e1c788cd100d45be001cc0',
#        'location': {'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.935798995450305,
#           'lng': 116.44859716097255}],
#         'lat': 39.935798995450305,
#         'lng': 116.44859716097255,
#         'state': '北京市'},
#        'name': 'ZWYN',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eed25162c5bafa618b5ac51-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4eed25162c5bafa618b5ac51',
#        'location': {'address': 'Sheraton Dongchen',
#         'cc': 'CN',
#         'country': '中国',
#         'crossStreet': '7th Floor Fitness Center',
#         'formattedAddress': ['Sheraton Dongchen (7th Floor Fitness Center)',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.9655090608214,
#           'lng': 116.4021416096858}],
#         'lat': 39.9655090608214,
#         'lng': 116.4021416096858},
#        'name': 'Sheraton Fitness Dongchen',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ed77872f7905836c0122fe3-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4ed77872f7905836c0122fe3',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91389855629263,
#           'lng': 116.41263716555979}],
#         'lat': 39.91389855629263,
#         'lng': 116.41263716555979},
#        'name': 'Legendale Hotel Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4de71171ae60db140a8ced97-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4de71171ae60db140a8ced97',
#        'location': {'address': '朝阳区东北四砾望京桥北 200 深田广自需濯小区',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['朝阳区东北四砾望京桥北 200 深田广自需濯小区', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.987044263426654,
#           'lng': 116.44861591567955}],
#         'lat': 39.987044263426654,
#         'lng': 116.44861591567955,
#         'state': '北京市'},
#        'name': '宜景阳光',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d0c682b903d37042555bd55-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4d0c682b903d37042555bd55',
#        'location': {'address': '东三环中路7号院',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': '朝阳区',
#         'formattedAddress': ['东三环中路7号院 (朝阳区)', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.915470053332534,
#           'lng': 116.45230395962705}],
#         'lat': 39.915470053332534,
#         'lng': 116.45230395962705,
#         'state': '北京市'},
#        'name': 'Gym - Grand Millennium',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-564a9f59498e8e6a5cda1b78-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '564a9f59498e8e6a5cda1b78',
#        'location': {'address': 'B1 NUO Hotel Beijing',
#         'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['B1 NUO Hotel Beijing, Dōng zhí mén', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.97504522348649,
#           'lng': 116.47475943628177}],
#         'lat': 39.97504522348649,
#         'lng': 116.47475943628177,
#         'neighborhood': 'Dōng zhí mén'},
#        'name': 'NUO Fitness | 诺金健身',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-530dc0e1498e90a545fa4a3b-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'primary': True,
#          'shortName': 'Office'}],
#        'id': '530dc0e1498e90a545fa4a3b',
#        'location': {'address': '43 N 3rd Ring Rd W',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'At Zhonghang Plaza',
#         'formattedAddress': ['43 N 3rd Ring Rd W (At Zhonghang Plaza)',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.97039456538491,
#           'lng': 116.32339239120483}],
#         'lat': 39.97039456538491,
#         'lng': 116.32339239120483,
#         'state': '北京市'},
#        'name': 'Bytedance HQ (字节跳动)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f0409042c5b145d0913f6af-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '4f0409042c5b145d0913f6af',
#        'location': {'address': '19, ChangWa, West 3rd Ring North Road',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'Haidian District',
#         'formattedAddress': ['19, ChangWa, West 3rd Ring North Road (Haidian District)',
#          '北京市',
#          '北京市, 100089',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.95748429213963,
#           'lng': 116.3038444519043}],
#         'lat': 39.95748429213963,
#         'lng': 116.3038444519043,
#         'postalCode': '100089',
#         'state': '北京市'},
#        'name': 'Huang Yuan Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd4104d462cb713bfb2df07-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4bd4104d462cb713bfb2df07',
#        'location': {'address': '9 Guanghua Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'At The Place, South Tower, L3/L4',
#         'formattedAddress': ['9 Guanghua Rd (At The Place, South Tower, L3/L4)',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91483163039875,
#           'lng': 116.44673153334918}],
#         'lat': 39.91483163039875,
#         'lng': 116.44673153334918,
#         'state': '北京市'},
#        'name': 'California Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50dd6b7ce4b04a54aa5d6d5c-40',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '50dd6b7ce4b04a54aa5d6d5c',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.92408766362841,
#           'lng': 116.47184386111459}],
#         'lat': 39.92408766362841,
#         'lng': 116.47184386111459},
#        'name': 'YOGASUMMIT',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eed71d902d514a36a133c92-41',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '4eed71d902d514a36a133c92',
#        'location': {'address': '9 Wenhuiyuan North Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'Haidian',
#         'formattedAddress': ['9 Wenhuiyuan North Rd (Haidian)',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.95131569787123,
#           'lng': 116.3542545918658}],
#         'lat': 39.95131569787123,
#         'lng': 116.3542545918658,
#         'state': '北京市'},
#        'name': '极度潜水俱乐部',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eed3980be7b6d620053c8be-42',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '4eed3980be7b6d620053c8be',
#        'location': {'address': 'Beijing',
#         'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['Beijing', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.96678749493186,
#           'lng': 116.40219924717748}],
#         'lat': 39.96678749493186,
#         'lng': 116.40219924717748},
#        'name': 'Sheraton pool',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-507525f8e4b084ad6e1f7520-43',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '507525f8e4b084ad6e1f7520',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91474739882203,
#           'lng': 116.41267174652289}],
#         'lat': 39.91474739882203,
#         'lng': 116.41267174652289},
#        'name': 'Regent Hotel Fitness Center',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d7daa806174a35df7777b03-44',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '4d7daa806174a35df7777b03',
#        'location': {'address': '127 Xuanwumen W Ave',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['127 Xuanwumen W Ave', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.89952087021196,
#           'lng': 116.35450520806845}],
#         'lat': 39.89952087021196,
#         'lng': 116.35450520806845,
#         'state': '北京市'},
#        'name': '大成大厦',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-509b4f98e4b0bd1e67501bea-45',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '509b4f98e4b0bd1e67501bea',
#        'location': {'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'Nearby Happy Valley',
#         'formattedAddress': ['Nearby Happy Valley', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.866117334537144,
#           'lng': 116.49518472597613}],
#         'lat': 39.866117334537144,
#         'lng': 116.49518472597613,
#         'state': '北京市'},
#        'name': 'Impulse Total Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-598040a6135b391886f9949a-46',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '503289d391d4c4b30a586d6a',
#          'name': 'Climbing Gym',
#          'pluralName': 'Climbing Gyms',
#          'primary': True,
#          'shortName': 'Climbing Gym'}],
#        'id': '598040a6135b391886f9949a',
#        'location': {'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.008962,
#           'lng': 116.344317}],
#         'lat': 40.008962,
#         'lng': 116.344317,
#         'state': '北京市'},
#        'name': '768攀岩馆',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-594b7505112c6c523a06b9c9-47',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b49',
#          'name': 'Cycle Studio',
#          'pluralName': 'Cycle Studios',
#          'primary': True,
#          'shortName': 'Cycle Studio'}],
#        'id': '594b7505112c6c523a06b9c9',
#        'location': {'address': 'China World Mall, NL3026',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['China World Mall, NL3026', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.909914716419095,
#           'lng': 116.45448535266564}],
#         'lat': 39.909914716419095,
#         'lng': 116.45448535266564,
#         'state': '北京市'},
#        'name': 'SpaceCycle',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57db6aca498e42f03c37dcf2-48',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b49',
#          'name': 'Cycle Studio',
#          'pluralName': 'Cycle Studios',
#          'primary': True,
#          'shortName': 'Cycle Studio'}],
#        'id': '57db6aca498e42f03c37dcf2',
#        'location': {'address': 'N4-40a, Taikoo Li Sanlitun North',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['N4-40a, Taikoo Li Sanlitun North',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.93703431258482,
#           'lng': 116.44783726299613}],
#         'lat': 39.93703431258482,
#         'lng': 116.44783726299613,
#         'state': '北京市'},
#        'name': 'SpaceCycle',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Beijing',
#   'headerLocation': 'Beijing',
#   'headerLocationGranularity': 'city',
#   'query': 'gym fitness',
#   'suggestedBounds': {'ne': {'lat': 40.056880354333565,
#     'lng': 116.63055877984611},
#    'sw': {'lat': 39.857033381213505, 'lng': 116.25603939143589}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 49}}

# %%
#Search results for local gym/fitness venue in Shanghai
results_gym[cities[1]]
# Out:
# {'meta': {'code': 200, 'requestId': '5f23ec665016ad2441acc8df'},
#  'response': {'geocode': {'cc': 'CN',
#    'center': {'lat': 31.22222, 'lng': 121.45806},
#    'displayString': 'Shanghai, Shanghai Shi, China',
#    'geometry': {'bounds': {'ne': {'lat': 31.87021999293653,
#       'lng': 121.98831988297854},
#      'sw': {'lat': 30.686803039798992, 'lng': 120.87753211035766}}},
#    'longId': '72057594039724172',
#    'slug': 'shanghai',
#    'what': '',
#    'where': 'shanghai shanghai'},
#   'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-545db149498ec40d66e3cf10-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '545db149498ec40d66e3cf10',
#        'location': {'address': '14/F 1219 Changle Rd',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': 'Wulumuqi Rd',
#         'formattedAddress': ["14/F 1219 Changle Rd (Wulumuqi Rd), Jìng'an",
#          'Xuhui',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.21662631501383,
#           'lng': 121.43777419625658}],
#         'lat': 31.21662631501383,
#         'lng': 121.43777419625658,
#         'neighborhood': "Jìng'an",
#         'state': '上海市'},
#        'name': 'Z&B Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-551a7032498e3548b3a5fbc9-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '551a7032498e3548b3a5fbc9',
#        'location': {'address': '501, Building B, 98-118 Jiashan Rd | 徐汇区嘉善路98-118楼B座501室',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': 'Yongkang Rd | 永康路',
#         'formattedAddress': ['501, Building B, 98-118 Jiashan Rd | 徐汇区嘉善路98-118楼B座501室 (Yongkang Rd | 永康路)',
#          'Xuhui',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.213463991847686,
#           'lng': 121.45450746777551}],
#         'lat': 31.213463991847686,
#         'lng': 121.45450746777551,
#         'state': '上海市'},
#        'name': 'The Clinic',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5acb5f7b9411f261769347e2-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5acb5f7b9411f261769347e2',
#        'location': {'address': '999 Huaihai M Rd | 淮海中路999号',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': 'iapm Mall | 环贸iapm商场',
#         'formattedAddress': ['999 Huaihai M Rd | 淮海中路999号 (iapm Mall | 环贸iapm商场)',
#          'Xuhui',
#          '上海市, 200031',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.21767607358868,
#           'lng': 121.45358559069659}],
#         'lat': 31.21767607358868,
#         'lng': 121.45358559069659,
#         'postalCode': '200031',
#         'state': '上海市'},
#        'name': 'Pure Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57da0726498e6e87ccf0ba1e-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '57da0726498e6e87ccf0ba1e',
#        'location': {'address': '278 Shaanxi N Rd | 陕西北路278号',
#         'cc': 'CN',
#         'city': "Jing'an",
#         'country': '中国',
#         'crossStreet': '6/F Golden Eagle Plaza | 金鹰国际购物中心',
#         'formattedAddress': ['278 Shaanxi N Rd | 陕西北路278号 (6/F Golden Eagle Plaza | 金鹰国际购物中心), Jìngʼān Temple',
#          "Jing'an",
#          '上海市, 200041',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.23020697828152,
#           'lng': 121.44982593631589}],
#         'lat': 31.23020697828152,
#         'lng': 121.44982593631589,
#         'neighborhood': 'Jìngʼān Temple',
#         'postalCode': '200041',
#         'state': '上海市'},
#        'name': 'Z&B Fitness Studio',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4de8152b52b1741cdafa0122-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4de8152b52b1741cdafa0122',
#        'location': {'address': '1388 Huamu Rd',
#         'cc': 'CN',
#         'city': '浦东',
#         'country': '中国',
#         'crossStreet': 'Fangdian Rd',
#         'formattedAddress': ['1388 Huamu Rd (Fangdian Rd)',
#          '浦东',
#          '上海市, 201204',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.215612230729327,
#           'lng': 121.55962922295144}],
#         'lat': 31.215612230729327,
#         'lng': 121.55962922295144,
#         'postalCode': '201204',
#         'state': '上海市'},
#        'name': 'Kerry Sports',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e0fcb08c65ba20da22e0b04-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4e0fcb08c65ba20da22e0b04',
#        'location': {'address': '7/F, The Portman Ritz-Carlton, 1376 Nanjing Rd. West',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': 'Xikang Rd.',
#         'formattedAddress': ['7/F, The Portman Ritz-Carlton, 1376 Nanjing Rd. West (Xikang Rd.)',
#          '上海市',
#          '上海市, 200040',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22978352019067,
#           'lng': 121.44681478846438}],
#         'lat': 31.22978352019067,
#         'lng': 121.44681478846438,
#         'postalCode': '200040',
#         'state': '上海市'},
#        'name': 'Portman Ritz-Carlton Health Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51c40933498ee2e82fef634a-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '51c40933498ee2e82fef634a',
#        'location': {'address': 'S2, Bldg 1, 667 Changhua Rd',
#         'cc': 'CN',
#         'city': 'Putuo',
#         'country': '中国',
#         'crossStreet': 'Anyuan Rd',
#         'formattedAddress': ['S2, Bldg 1, 667 Changhua Rd (Anyuan Rd)',
#          'Putuo',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.243379206539768,
#           'lng': 121.44272451141694}],
#         'lat': 31.243379206539768,
#         'lng': 121.44272451141694,
#         'state': '上海市'},
#        'name': 'Reebok CrossFit MeWellness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e6549407d8b85408ae2f0c1-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4e6549407d8b85408ae2f0c1',
#        'location': {'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'formattedAddress': ['上海市', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.247185869153395,
#           'lng': 121.48860930796023}],
#         'lat': 31.247185869153395,
#         'lng': 121.48860930796023,
#         'state': '上海市'},
#        'name': 'Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-522ee92f11d2c78601722c45-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '522ee92f11d2c78601722c45',
#        'location': {'cc': 'CN',
#         'city': 'Huangpu',
#         'country': '中国',
#         'formattedAddress': ['Huangpu', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.222201454247205,
#           'lng': 121.47284666833274}],
#         'lat': 31.222201454247205,
#         'lng': 121.47284666833274,
#         'state': '上海市'},
#        'name': "Will's Gym | 威尔士健身Xintiandi",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bede78d2c082d7fbab52f42-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4bede78d2c082d7fbab52f42',
#        'location': {'address': '168 Shunchang Rd',
#         'cc': 'CN',
#         'city': 'Huangpu',
#         'country': '中国',
#         'crossStreet': 'Zizhong Rd',
#         'formattedAddress': ['168 Shunchang Rd (Zizhong Rd)',
#          'Huangpu',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.219862185116163,
#           'lng': 121.47247291245648}],
#         'lat': 31.219862185116163,
#         'lng': 121.47247291245648,
#         'state': '上海市'},
#        'name': 'Lakeville Clubhouse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfa6edf52b1a82364e69862-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4dfa6edf52b1a82364e69862',
#        'location': {'address': '789 Nanjing E Rd',
#         'cc': 'CN',
#         'city': 'Huangpu',
#         'country': '中国',
#         'crossStreet': 'Jiujiang Rd',
#         'formattedAddress': ['789 Nanjing E Rd (Jiujiang Rd)',
#          'Huangpu',
#          '上海市, 200001',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.236337539840378,
#           'lng': 121.4710448960275}],
#         'lat': 31.236337539840378,
#         'lng': 121.4710448960275,
#         'postalCode': '200001',
#         'state': '上海市'},
#        'name': 'Le Royal Méridien Shanghai - Gym & Spa',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '78909801'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51fd9c24498ebd46bcf18e02-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '51fd9c24498ebd46bcf18e02',
#        'location': {'address': "1218 Middle Yan'an Road",
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': 'West Nanjing Road, Jingan Shangri-la Hotel',
#         'formattedAddress': ["1218 Middle Yan'an Road (West Nanjing Road, Jingan Shangri-la Hotel)",
#          '上海市',
#          '上海市, 200040',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.224691594990357,
#           'lng': 121.44542179161213}],
#         'lat': 31.224691594990357,
#         'lng': 121.44542179161213,
#         'postalCode': '200040',
#         'state': '上海市'},
#        'name': 'The Chi Spa And Fitness Center',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b5bcea7f964a5204d1729e3-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4b5bcea7f964a5204d1729e3',
#        'location': {'address': 'Lane 95 Wuyi Rd, Room 205',
#         'cc': 'CN',
#         'city': 'Changning',
#         'country': '中国',
#         'crossStreet': 'Yanan Rd',
#         'formattedAddress': ['Lane 95 Wuyi Rd, Room 205 (Yanan Rd)',
#          'Changning',
#          '上海市, 200050',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.216223244787123,
#           'lng': 121.42487329815225}],
#         'lat': 31.216223244787123,
#         'lng': 121.42487329815225,
#         'postalCode': '200050',
#         'state': '上海市'},
#        'name': 'Bodyworks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54be5796498e312c6e0835dd-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '54be5796498e312c6e0835dd',
#        'location': {'address': '68 Yuyuan Rd | 愚园路68号',
#         'cc': 'CN',
#         'city': "Jing'an",
#         'country': '中国',
#         'crossStreet': '5/F Crystal Galleria Mall | 晶品',
#         'formattedAddress': ['68 Yuyuan Rd | 愚园路68号 (5/F Crystal Galleria Mall | 晶品), Jìngʼān Temple',
#          "Jing'an",
#          '上海市, 200040',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22707822027757,
#           'lng': 121.44191672659632}],
#         'lat': 31.22707822027757,
#         'lng': 121.44191672659632,
#         'neighborhood': 'Jìngʼān Temple',
#         'postalCode': '200040',
#         'state': '上海市'},
#        'name': 'Physical (舒适堡)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53f9cf1b498eae90b88a7263-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '53f9cf1b498eae90b88a7263',
#        'location': {'address': '1515 Nanjing Road West',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': "Jing'an Kerry Centre",
#         'formattedAddress': ["1515 Nanjing Road West (Jing'an Kerry Centre)",
#          '上海市',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.225624520998416,
#           'lng': 121.44560065222639}],
#         'lat': 31.225624520998416,
#         'lng': 121.44560065222639,
#         'state': '上海市'},
#        'name': 'Kerry Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55a8de37498ee90cd7b2b0be-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '55a8de37498ee90cd7b2b0be',
#        'location': {'address': 'Wanghangdu Rd',
#         'cc': 'CN',
#         'city': 'Jing’an',
#         'country': '中国',
#         'crossStreet': 'near Zhenning Rd',
#         'formattedAddress': ['Wanghangdu Rd (near Zhenning Rd)',
#          'Jing’an',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22688785367926,
#           'lng': 121.43173914592887}],
#         'lat': 31.22688785367926,
#         'lng': 121.43173914592887,
#         'state': '上海市'},
#        'name': "Will's Gym",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fcf2ce3e4b05190be18d6ad-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4fcf2ce3e4b05190be18d6ad',
#        'location': {'address': '55 Zhenning Rd | 镇宁路55号',
#         'cc': 'CN',
#         'city': 'Changning',
#         'country': '中国',
#         'crossStreet': 'Zhaohua E Rd | 昭化东路',
#         'formattedAddress': ['55 Zhenning Rd | 镇宁路55号 (Zhaohua E Rd | 昭化东路), Jiāngsūlù',
#          'Changning',
#          '上海市, 200050',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.21703721758933,
#           'lng': 121.43325863597745}],
#         'lat': 31.21703721758933,
#         'lng': 121.43325863597745,
#         'neighborhood': 'Jiāngsūlù',
#         'postalCode': '200050',
#         'state': '上海市'},
#        'name': 'Tera Wellness Club (一兆韦德)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cd9ecd96c25b60c3777d34f-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4cd9ecd96c25b60c3777d34f',
#        'location': {'address': '796 Dongfang Rd | 东方路796号',
#         'cc': 'CN',
#         'city': '浦东',
#         'country': '中国',
#         'crossStreet': 'B1/F Plaza 96 | 96广场',
#         'formattedAddress': ['796 Dongfang Rd | 东方路796号 (B1/F Plaza 96 | 96广场), Lùjiāzuǐ',
#          '浦东',
#          '上海市, 200122',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22955136505756,
#           'lng': 121.52026057547009}],
#         'lat': 31.22955136505756,
#         'lng': 121.52026057547009,
#         'neighborhood': 'Lùjiāzuǐ',
#         'postalCode': '200122',
#         'state': '上海市'},
#        'name': "Will's Gym (威尔士健身)",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bfca980bf6576b0ac3facb8-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4bfca980bf6576b0ac3facb8',
#        'location': {'address': '166 Luban Rd',
#         'cc': 'CN',
#         'city': 'Huangpu',
#         'country': '中国',
#         'formattedAddress': ['166 Luban Rd', 'Huangpu', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.207722398947766,
#           'lng': 121.4696446010803}],
#         'lat': 31.207722398947766,
#         'lng': 121.4696446010803,
#         'state': '上海市'},
#        'name': "Will's Fitness (威尔士健身)",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52db7ce8498e64dba22f5ac8-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '52db7ce8498e64dba22f5ac8',
#        'location': {'address': '淮海中路527号锦江国际购物中心7楼',
#         'cc': 'CN',
#         'city': 'Huangpu',
#         'country': '中国',
#         'crossStreet': '成都南路',
#         'formattedAddress': ['淮海中路527号锦江国际购物中心7楼 (成都南路), Xīntiāndì',
#          'Huangpu',
#          '上海市, 200085',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.222508474582888,
#           'lng': 121.4644340785019}],
#         'lat': 31.222508474582888,
#         'lng': 121.4644340785019,
#         'neighborhood': 'Xīntiāndì',
#         'postalCode': '200085',
#         'state': '上海市'},
#        'name': 'Physical (舒适堡)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c57fd5a7329c9284ffe8f80-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4c57fd5a7329c9284ffe8f80',
#        'location': {'address': '88 Huichuan Rd',
#         'cc': 'CN',
#         'city': 'Changning',
#         'country': '中国',
#         'crossStreet': '中山公园店 at 凯欣豪园',
#         'formattedAddress': ['88 Huichuan Rd (中山公园店 at 凯欣豪园)',
#          'Changning',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.21842151994381,
#           'lng': 121.41368812176229}],
#         'lat': 31.21842151994381,
#         'lng': 121.41368812176229,
#         'state': '上海市'},
#        'name': "Will's Gym (威尔士健身)",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5383f7d2498e54d58e8e1e89-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '5383f7d2498e54d58e8e1e89',
#        'location': {'address': '357 Jianguo W Rd | 建国西路357号',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': 'Taiyuan Rd | 太原路',
#         'formattedAddress': ['357 Jianguo W Rd | 建国西路357号 (Taiyuan Rd | 太原路), Xúhuì',
#          'Xuhui',
#          '上海市, 200031',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.206110559257233,
#           'lng': 121.45138585616215}],
#         'lat': 31.206110559257233,
#         'lng': 121.45138585616215,
#         'neighborhood': 'Xúhuì',
#         'postalCode': '200031',
#         'state': '上海市'},
#        'name': 'The Living Room by Octave (The Living Room by Octave (Living Room by Octave | 音昱听堂))',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c4b8321c668e21eebf824fa-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4c4b8321c668e21eebf824fa',
#        'location': {'address': '河南中路1号城市会所',
#         'cc': 'CN',
#         'city': 'Huangpu',
#         'country': '中国',
#         'formattedAddress': ['河南中路1号城市会所', 'Huangpu', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.23365292124738,
#           'lng': 121.48124190985376}],
#         'lat': 31.23365292124738,
#         'lng': 121.48124190985376,
#         'state': '上海市'},
#        'name': 'Tera Wellness Club (一兆韦德健身会所)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b964e46f964a52011c534e3-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4b964e46f964a52011c534e3',
#        'location': {'address': '135 Jianguo (W) Rd | 建国西路135号',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': 'Shaanxi (S) Rd | 陕西南路',
#         'formattedAddress': ['135 Jianguo (W) Rd | 建国西路135号 (Shaanxi (S) Rd | 陕西南路), Xīntiāndì',
#          'Huángpǔ',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.209007406792654,
#           'lng': 121.45955806574847}],
#         'lat': 31.209007406792654,
#         'lng': 121.45955806574847,
#         'neighborhood': 'Xīntiāndì',
#         'state': '上海市'},
#        'name': 'Luwan Gymnasium (卢湾体育馆)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52554fde11d284f8250b162f-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '52554fde11d284f8250b162f',
#        'location': {'address': '999 Huaihai M Rd | 淮海中路999号',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': '6/F iapm Mall | 环贸iapm商场',
#         'formattedAddress': ['999 Huaihai M Rd | 淮海中路999号 (6/F iapm Mall | 环贸iapm商场)',
#          'Xuhui',
#          '上海市, 200031',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.217579558268255,
#           'lng': 121.45328355137916}],
#         'lat': 31.217579558268255,
#         'lng': 121.45328355137916,
#         'postalCode': '200031',
#         'state': '上海市'},
#        'name': 'Pure Yoga',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-522c184111d2b982ba5940dd-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '522c184111d2b982ba5940dd',
#        'location': {'address': '陕西南路5-7号城市酒店6楼',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': '延安中路',
#         'formattedAddress': ['陕西南路5-7号城市酒店6楼 (延安中路), Jìngān',
#          '上海市',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.224801993123677,
#           'lng': 121.45287009068755}],
#         'lat': 31.224801993123677,
#         'lng': 121.45287009068755,
#         'neighborhood': 'Jìngān',
#         'state': '上海市'},
#        'name': 'Mr & Mrs Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc6e3406501c9b6df703d29-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4bc6e3406501c9b6df703d29',
#        'location': {'address': '945 Xinzha Rd | 新闸路945号',
#         'cc': 'CN',
#         'city': "Jing'an",
#         'country': '中国',
#         'crossStreet': '国际丽都城群楼3楼',
#         'formattedAddress': ['945 Xinzha Rd | 新闸路945号 (国际丽都城群楼3楼), Jìngʼān',
#          "Jing'an",
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.235742569931972,
#           'lng': 121.45338828056006}],
#         'lat': 31.235742569931972,
#         'lng': 121.45338828056006,
#         'neighborhood': 'Jìngʼān',
#         'state': '上海市'},
#        'name': 'Mind Over Body Fitness (MOB)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e608e6fd22d509a38ca04a5-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4e608e6fd22d509a38ca04a5',
#        'location': {'address': '远景路97弄中远两湾城23号 | 97 Yuanjing Rd.',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': '近上海火车站 | Shanghai Railway Station',
#         'formattedAddress': ['远景路97弄中远两湾城23号 | 97 Yuanjing Rd. (近上海火车站 | Shanghai Railway Station)',
#          '上海市',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.25391131888267,
#           'lng': 121.44309302685006}],
#         'lat': 31.25391131888267,
#         'lng': 121.44309302685006,
#         'state': '上海市'},
#        'name': 'Tera Wellness Club (一兆韦德健身会所)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d5df316196ba093364dfc55-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4d5df316196ba093364dfc55',
#        'location': {'address': '580 Tianyaoqiao Rd | 天钥桥路580号',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': 'B2/F In Center Mall | 星游城',
#         'formattedAddress': ['580 Tianyaoqiao Rd | 天钥桥路580号 (B2/F In Center Mall | 星游城), Xújiāhuì',
#          'Xuhui',
#          '上海市, 200030',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.187586391226596,
#           'lng': 121.4377668365343}],
#         'lat': 31.187586391226596,
#         'lng': 121.4377668365343,
#         'neighborhood': 'Xújiāhuì',
#         'postalCode': '200030',
#         'state': '上海市'},
#        'name': "Will's Gym (威尔士健身)",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53758938498e834844ec5c41-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '53758938498e834844ec5c41',
#        'location': {'address': '118 Shimen 1st Rd | 石门一路118号',
#         'cc': 'CN',
#         'city': "Jing'an",
#         'country': '中国',
#         'crossStreet': 'Weining Rd | 威海路',
#         'formattedAddress': ['118 Shimen 1st Rd | 石门一路118号 (Weining Rd | 威海路)',
#          "Jing'an",
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22888239739121,
#           'lng': 121.45862349847287}],
#         'lat': 31.22888239739121,
#         'lng': 121.45862349847287,
#         'state': '上海市'},
#        'name': "Will's Fitness (威尔士健身)",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5066fbbde4b08b322065936a-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5066fbbde4b08b322065936a',
#        'location': {'address': 'B1, Greenland Puhui International Center, 868 E Longhua Rd',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'formattedAddress': ['B1, Greenland Puhui International Center, 868 E Longhua Rd',
#          '上海市',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.19524929024058,
#           'lng': 121.46883655679449}],
#         'lat': 31.19524929024058,
#         'lng': 121.46883655679449,
#         'state': '上海市'},
#        'name': 'Physical 舒适堡 (舒适堡)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-592ebd0231ac6c14dcb45586-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '592ebd0231ac6c14dcb45586',
#        'location': {'address': '807-101 Zhaojiabang Rd',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': "Gao'an Rd",
#         'formattedAddress': ["807-101 Zhaojiabang Rd (Gao'an Rd), Hù jiā huī",
#          'Xuhui',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.200287285525317,
#           'lng': 121.443366440425}],
#         'lat': 31.200287285525317,
#         'lng': 121.443366440425,
#         'neighborhood': 'Hù jiā huī',
#         'state': '上海市'},
#        'name': 'Super Monkey (超级猩猩)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-504ae318e4b09ff98acf476a-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '504ae318e4b09ff98acf476a',
#        'location': {'address': '3211 Hongmei Lu 5/F',
#         'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['3211 Hongmei Lu 5/F', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.188901456006803,
#           'lng': 121.3834567040613}],
#         'lat': 31.188901456006803,
#         'lng': 121.3834567040613},
#        'name': 'Body Concept',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-569b6a81498e49ebb12783bd-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '569b6a81498e49ebb12783bd',
#        'location': {'address': '西康路99号',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'formattedAddress': ['西康路99号', '上海市', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.229856703753416,
#           'lng': 121.44771865103198}],
#         'lat': 31.229856703753416,
#         'lng': 121.44771865103198,
#         'state': '上海市'},
#        'name': 'Sweat & Co',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5ce684b865211f002cbb4924-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5ce684b865211f002cbb4924',
#        'location': {'cc': 'CN',
#         'city': '浦东',
#         'country': '中国',
#         'formattedAddress': ['Pǔdōng', '浦东', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.231237325749863,
#           'lng': 121.52317643165588}],
#         'lat': 31.231237325749863,
#         'lng': 121.52317643165588,
#         'neighborhood': 'Pǔdōng',
#         'state': '上海市'},
#        'name': 'SUPERMONKEY',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e86772777c8edfe5ad50fdd-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4e86772777c8edfe5ad50fdd',
#        'location': {'cc': 'CN',
#         'city': '浦东',
#         'country': '中国',
#         'crossStreet': 'Crowne Plaza Hotel',
#         'formattedAddress': ['Gāoqiáo', '浦东', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.341238601347634,
#           'lng': 121.5864510748909}],
#         'lat': 31.341238601347634,
#         'lng': 121.5864510748909,
#         'neighborhood': 'Gāoqiáo',
#         'state': '上海市'},
#        'name': 'Fitness Centre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-513887e6e4b071615848045e-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '513887e6e4b071615848045e',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.228963128352607,
#           'lng': 121.45844224437751}],
#         'lat': 31.228963128352607,
#         'lng': 121.45844224437751},
#        'name': 'Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f3c5230e4b08112230d57e6-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4f3c5230e4b08112230d57e6',
#        'location': {'address': 'Jumeirah Himalayas Hotel, 1108 Mei Hua Rd',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': 'Fangdian Rd',
#         'formattedAddress': ['Jumeirah Himalayas Hotel, 1108 Mei Hua Rd (Fangdian Rd)',
#          '上海市',
#          '上海市, 201204',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.212145436629193,
#           'lng': 121.557476161153}],
#         'lat': 31.212145436629193,
#         'lng': 121.557476161153,
#         'postalCode': '201204',
#         'state': '上海市'},
#        'name': 'Health Club (武)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a62b652d41bb717643dfb73-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5a62b652d41bb717643dfb73',
#        'location': {'address': '333 Tianyaoqiao Rd | 天钥桥路333号',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': '2/F Ascendas Plaza | 腾飞大厦',
#         'formattedAddress': ['333 Tianyaoqiao Rd | 天钥桥路333号 (2/F Ascendas Plaza | 腾飞大厦), Xújiāhuì',
#          'Xuhui',
#          '上海市, 200030',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.189589,
#           'lng': 121.437945}],
#         'lat': 31.189589,
#         'lng': 121.437945,
#         'neighborhood': 'Xújiāhuì',
#         'postalCode': '200030',
#         'state': '上海市'},
#        'name': 'Super Monkey',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bd2fe322be425002c674f84-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5bd2fe322be425002c674f84',
#        'location': {'address': '282 Huaihai M Rd | 淮海中路282号',
#         'cc': 'CN',
#         'city': 'Huangpu',
#         'country': '中国',
#         'crossStreet': '4/F-02 N Hongkong Plaza | 香港广场',
#         'formattedAddress': ['282 Huaihai M Rd | 淮海中路282号 (4/F-02 N Hongkong Plaza | 香港广场), Huáihǎi Zhōnglù',
#          'Huangpu',
#          '上海市, 200021',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22559139638689,
#           'lng': 121.47022477317564}],
#         'lat': 31.22559139638689,
#         'lng': 121.47022477317564,
#         'neighborhood': 'Huáihǎi Zhōnglù',
#         'postalCode': '200021',
#         'state': '上海市'},
#        'name': 'Z&B Fitness Xintiandi',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
# ...
#        'name': 'Alexander Health Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-561e2bd7498e4e23a8b761d7-86',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '561e2bd7498e4e23a8b761d7',
#        'location': {'address': '100 Zunyi Rd | 遵义路100号',
#         'cc': 'CN',
#         'city': 'Changning',
#         'country': '中国',
#         'crossStreet': '6/F S The Place | 南丰城',
#         'formattedAddress': ['100 Zunyi Rd | 遵义路100号 (6/F S The Place | 南丰城), Xiānxiá',
#          'Changning',
#          '上海市, 200051',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.209654854133912,
#           'lng': 121.40303246177609}],
#         'lat': 31.209654854133912,
#         'lng': 121.40303246177609,
#         'neighborhood': 'Xiānxiá',
#         'postalCode': '200051',
#         'state': '上海市'},
#        'name': "Will's Gym (威尔士健身)",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e7735861f6e072f146f0413-87',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4e7735861f6e072f146f0413',
#        'location': {'address': '98 Shouning Road',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'formattedAddress': ['98 Shouning Road, Lǎo běi mén',
#          '上海市',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22567931917436,
#           'lng': 121.47644201804646}],
#         'lat': 31.22567931917436,
#         'lng': 121.47644201804646,
#         'neighborhood': 'Lǎo běi mén',
#         'state': '上海市'},
#        'name': 'Fraser Residence Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-527b9523498e687e45f206e3-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '527b9523498e687e45f206e3',
#        'location': {'cc': 'CN',
#         'city': '浦东',
#         'country': '中国',
#         'formattedAddress': ['浦东', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.151762283711815,
#           'lng': 121.57187914834462}],
#         'lat': 31.151762283711815,
#         'lng': 121.57187914834462,
#         'state': '上海市'},
#        'name': 'Kingsports (金仕堡)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d6a0d554c463704017aabb3-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4d6a0d554c463704017aabb3',
#        'location': {'address': '成山路1879号',
#         'cc': 'CN',
#         'city': '浦东',
#         'country': '中国',
#         'formattedAddress': ['成山路1879号', '浦东', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.180309396686077,
#           'lng': 121.5273295100074}],
#         'lat': 31.180309396686077,
#         'lng': 121.5273295100074,
#         'state': '上海市'},
#        'name': 'Tera Wellness Club (一兆韦德健身会所)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b150d99c58ed7002c2b8fba-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '5b150d99c58ed7002c2b8fba',
#        'location': {'cc': 'CN',
#         'city': 'Putuo',
#         'country': '中国',
#         'crossStreet': '中港汇大厦',
#         'formattedAddress': ['Putuo', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.237633,
#           'lng': 121.426279}],
#         'lat': 31.237633,
#         'lng': 121.426279,
#         'state': '上海市'},
#        'name': 'Supermonkey',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d4e555f4f67224bb6d76150-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4d4e555f4f67224bb6d76150',
#        'location': {'address': '367 Pucheng Rd | 浦城路367号',
#         'cc': 'CN',
#         'city': '浦东',
#         'country': '中国',
#         'formattedAddress': ['367 Pucheng Rd | 浦城路367号', '浦东', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22937597010276,
#           'lng': 121.50814160356629}],
#         'lat': 31.22937597010276,
#         'lng': 121.50814160356629,
#         'state': '上海市'},
#        'name': 'Tera Wellness Club (一兆韦德健身会所)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbf13dc85fbb71338927167-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4bbf13dc85fbb71338927167',
#        'location': {'address': '长宁路1018号12楼 | 1018 Changning Rd.',
#         'cc': 'CN',
#         'city': 'Changning',
#         'country': '中国',
#         'crossStreet': '龙之梦 | Cloud Nine',
#         'formattedAddress': ['长宁路1018号12楼 | 1018 Changning Rd. (龙之梦 | Cloud Nine)',
#          'Changning',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.220558214855053,
#           'lng': 121.412536332737}],
#         'lat': 31.220558214855053,
#         'lng': 121.412536332737,
#         'state': '上海市'},
#        'name': 'Tera Wellness Club (一兆韦德健身会所)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf91edbc07c9c7415f7bbef-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4bf91edbc07c9c7415f7bbef',
#        'location': {'address': '387 Panyu Rd',
#         'cc': 'CN',
#         'city': 'Changning',
#         'country': '中国',
#         'crossStreet': '番禺店',
#         'formattedAddress': ['387 Panyu Rd (番禺店)', 'Changning', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.205815642408687,
#           'lng': 121.42542035206434}],
#         'lat': 31.205815642408687,
#         'lng': 121.42542035206434,
#         'state': '上海市'},
#        'name': "Will's Gym | 威尔士健身",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f5ae5fde4b09f0f9756f878-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4f5ae5fde4b09f0f9756f878',
#        'location': {'address': '601 FengYang Lu',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': 'DaTian Lu',
#         'formattedAddress': ['601 FengYang Lu (DaTian Lu)',
#          '上海市',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.234177375724148,
#           'lng': 121.46051154276756}],
#         'lat': 31.234177375724148,
#         'lng': 121.46051154276756,
#         'state': '上海市'},
#        'name': 'Tera Wellness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f730770e4b02c6aeee8375d-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '4f730770e4b02c6aeee8375d',
#        'location': {'address': '500, Weihai Lu',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'crossStreet': 'Shimen yi Lu',
#         'formattedAddress': ['500, Weihai Lu (Shimen yi Lu)',
#          '上海市',
#          '上海市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22914906948849,
#           'lng': 121.45794570039806}],
#         'lat': 31.22914906948849,
#         'lng': 121.45794570039806,
#         'state': '上海市'},
#        'name': 'Yoga @ Four Seasons, Shanghai',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-582065ccfa17e5344a61e477-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '582065ccfa17e5344a61e477',
#        'location': {'address': '3/F-35 1266 Nanjing W Rd | 南京西路1266号恒隆广场3楼',
#         'cc': 'CN',
#         'city': 'Jing’an',
#         'country': '中国',
#         'crossStreet': 'Xikang Rd | 西康路',
#         'formattedAddress': ['3/F-35 1266 Nanjing W Rd | 南京西路1266号恒隆广场3楼 (Xikang Rd | 西康路), Jìngān',
#          'Jing’an',
#          '200040',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22997819876834,
#           'lng': 121.44863524471893}],
#         'lat': 31.22997819876834,
#         'lng': 121.44863524471893,
#         'neighborhood': 'Jìngān',
#         'postalCode': '200040'},
#        'name': 'Pure Yoga',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-578cdc32498e194174d5b1f1-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '578cdc32498e194174d5b1f1',
#        'location': {'cc': 'CN',
#         'city': 'Changning',
#         'country': '中国',
#         'formattedAddress': ['Changning', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.22509691805425,
#           'lng': 121.42471145616061}],
#         'lat': 31.22509691805425,
#         'lng': 121.42471145616061,
#         'state': '上海市'},
#        'name': 'Drishti Vinyasa Yoga Shala',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b8ba7c5f964a520d4a532e3-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '4b8ba7c5f964a520d4a532e3',
#        'location': {'address': '枫林路329号',
#         'cc': 'CN',
#         'city': 'Xuhui',
#         'country': '中国',
#         'crossStreet': '零陵路',
#         'formattedAddress': ['枫林路329号 (零陵路)', 'Xuhui', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.19517042146655,
#           'lng': 121.45241913325526}],
#         'lat': 31.19517042146655,
#         'lng': 121.45241913325526,
#         'state': '上海市'},
#        'name': '徐汇游泳馆',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bfd20bcb68d0f471445e857-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '4bfd20bcb68d0f471445e857',
#        'location': {'address': '浦东南路3669号',
#         'cc': 'CN',
#         'city': '上海市',
#         'country': '中国',
#         'formattedAddress': ['浦东南路3669号', '上海市', '上海市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.19090179571385,
#           'lng': 121.50084701541036}],
#         'lat': 31.19090179571385,
#         'lng': 121.50084701541036,
#         'state': '上海市'},
#        'name': '浦东游泳馆',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Shanghai',
#   'headerLocation': 'Shanghai',
#   'headerLocationGranularity': 'city',
#   'query': 'gym fitness',
#   'suggestedBounds': {'ne': {'lat': 31.350712417229424,
#     'lng': 121.60954789617892},
#    'sw': {'lat': 31.142288467830028, 'lng': 121.35404056974687}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 104}}

# %%
#search results for local gym/fitness venue in Chengdu
results_gym[cities[2]]
# Out:
# {'meta': {'code': 200, 'requestId': '5f23ef14b746232b3032077d'},
#  'response': {'geocode': {'cc': 'CN',
#    'center': {'lat': 30.66667, 'lng': 104.06667},
#    'displayString': 'Chengdu, Sichuan Sheng, China',
#    'geometry': {'bounds': {'ne': {'lat': 30.84052023685318,
#       'lng': 104.320124806034},
#      'sw': {'lat': 30.491727821607, 'lng': 103.80486859136296}}},
#    'longId': '72057594039743222',
#    'slug': 'chengdu',
#    'what': '',
#    'where': 'chengdu sichuan'},
#   'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e7918f252b1fc6a4ab978d4-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4e7918f252b1fc6a4ab978d4',
#        'location': {'address': 'InterContinental Hotel',
#         'cc': 'CN',
#         'city': '成都市',
#         'country': '中国',
#         'formattedAddress': ['InterContinental Hotel', '成都市', '四川', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.561565384368965,
#           'lng': 104.0701682675925}],
#         'lat': 30.561565384368965,
#         'lng': 104.0701682675925,
#         'state': '四川'},
#        'name': 'InterContinental Fitness Center',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54d4c0f0498ea0e079ac2a7d-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '54d4c0f0498ea0e079ac2a7d',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.66366000042499,
#           'lng': 104.07197690006174}],
#         'lat': 30.66366000042499,
#         'lng': 104.07197690006174},
#        'name': 'St Regis Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-543752e8498ee8034f20a123-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '543752e8498ee8034f20a123',
#        'location': {'cc': 'CN',
#         'city': '成都市',
#         'country': '中国',
#         'crossStreet': '万年城',
#         'formattedAddress': ['万年城', '成都市', '四川', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.655024558434228,
#           'lng': 104.11293187901114}],
#         'lat': 30.655024558434228,
#         'lng': 104.11293187901114,
#         'state': '四川'},
#        'name': '传奇健身 (Legend Fitness)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55863dec498e2138f0cfa642-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '55863dec498e2138f0cfa642',
#        'location': {'address': '瑜伽中心IFS',
#         'cc': 'CN',
#         'city': '成都市',
#         'country': '中国',
#         'formattedAddress': ['瑜伽中心IFS', '成都市', '四川', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.65730938362122,
#           'lng': 104.07763884481295}],
#         'lat': 30.65730938362122,
#         'lng': 104.07763884481295,
#         'state': '四川'},
#        'name': '舒适堡健身 (Physical Fitness)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f4af9ace4b0605e453049d2-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4f4af9ace4b0605e453049d2',
#        'location': {'address': '优品道广场',
#         'cc': 'CN',
#         'city': '成都市',
#         'country': '中国',
#         'formattedAddress': ['优品道广场', '成都市', '四川', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.666688200476962,
#           'lng': 104.00502707263638}],
#         'lat': 30.666688200476962,
#         'lng': 104.00502707263638,
#         'state': '四川'},
#        'name': 'Pioneer Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-512d3ff2e4b02d7ac4edec04-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '512d3ff2e4b02d7ac4edec04',
#        'location': {'cc': 'CN',
#         'city': '成都市',
#         'country': '中国',
#         'formattedAddress': ['成都市', '四川', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.645684219675935,
#           'lng': 104.0832682037514}],
#         'lat': 30.645684219675935,
#         'lng': 104.0832682037514,
#         'state': '四川'},
#        'name': 'Shangri-La Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f5bf170e4b0a61f4b9a664a-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4f5bf170e4b0a61f4b9a664a',
#        'location': {'address': '111, Zhihui Street, Jinjiang District',
#         'cc': 'CN',
#         'city': '成都市',
#         'country': '中国',
#         'formattedAddress': ['111, Zhihui Street, Jinjiang District',
#          '成都市',
#          '四川, 610016',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.654741562025055,
#           'lng': 104.06678856922395}],
#         'lat': 30.654741562025055,
#         'lng': 104.06678856922395,
#         'postalCode': '610016',
#         'state': '四川'},
#        'name': 'Fraser Suites Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-559c487d498ea2f0a996f036-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d105941735',
#          'name': 'Gym Pool',
#          'pluralName': 'Gym Pools',
#          'primary': True,
#          'shortName': 'Pool'}],
#        'id': '559c487d498ea2f0a996f036',
#        'location': {'address': '23/F, The Ritz Carlton, 269 Shun cheng Avenue, Qinhuangdao District',
#         'cc': 'CN',
#         'city': '成都市',
#         'country': '中国',
#         'formattedAddress': ['23/F, The Ritz Carlton, 269 Shun cheng Avenue, Qinhuangdao District',
#          '成都市',
#          '四川, 610017',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.666291903174624,
#           'lng': 104.0676391567754}],
#         'lat': 30.666291903174624,
#         'lng': 104.0676391567754,
#         'postalCode': '610017',
#         'state': '四川'},
#        'name': 'Fitness Center at the Ritz Carlton',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Chengdu',
#   'headerLocation': 'Chengdu',
#   'headerLocationGranularity': 'city',
#   'query': 'gym fitness',
#   'suggestedBounds': {'ne': {'lat': 30.671944341282362,
#     'lng': 104.11832711932988},
#    'sw': {'lat': 30.556309243563568, 'lng': 103.99963183231765}},
#   'totalResults': 8}}

# %%
#search results for local gym/fitness venue in Chongqing
results_gym[cities[3]]
# Out:
# {'meta': {'code': 200, 'requestId': '5f23ef4162c02d6bfb4cc9fe'},
#  'response': {'geocode': {'cc': 'CN',
#    'center': {'lat': 29.56278, 'lng': 106.55278},
#    'displayString': 'Chongqing, Chongqing Shi, China',
#    'geometry': {'bounds': {'ne': {'lat': 29.753100915005113,
#       'lng': 106.67501805335111},
#      'sw': {'lat': 29.26274195138363, 'lng': 106.27432593278299}}},
#    'longId': '72057594039742842',
#    'slug': 'chongqing',
#    'what': '',
#    'where': 'chongqing chongqing'},
#   'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a79da23f0b49079b610e15e-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5a79da23f0b49079b610e15e',
#        'location': {'address': 'No.55 Xiejiawan Main Street',
#         'cc': 'CN',
#         'city': '重庆市',
#         'country': '中国',
#         'formattedAddress': ['No.55 Xiejiawan Main Street',
#          '重庆市',
#          '重庆市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.517658,
#           'lng': 106.51906}],
#         'lat': 29.517658,
#         'lng': 106.51906,
#         'state': '重庆市'},
#        'name': 'whytewoolf fitness club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'flags': {'outsideRadius': True},
#       'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53357a8d498e1087fbf7839d-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '53357a8d498e1087fbf7839d',
#        'location': {'address': '协信 星光时代广场',
#         'cc': 'CN',
#         'city': '重庆市',
#         'country': '中国',
#         'formattedAddress': ['协信 星光时代广场', '重庆市', '重庆市, 400060', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.61896484510964,
#           'lng': 106.50941006826359}],
#         'lat': 29.61896484510964,
#         'lng': 106.50941006826359,
#         'postalCode': '400060',
#         'state': '重庆市'},
#        'name': 'Comjoy凯健国际健身 南坪店',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a464cbf911fc41c779e84ba-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5a464cbf911fc41c779e84ba',
#        'location': {'cc': 'CN',
#         'city': '重庆市',
#         'country': '中国',
#         'formattedAddress': ['重庆市', '重庆市, 401147', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.58337,
#           'lng': 106.532234}],
#         'lat': 29.58337,
#         'lng': 106.532234,
#         'postalCode': '401147',
#         'state': '重庆市'},
#        'name': 'Hyatt Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54aa55b6498ea66986786a58-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '54aa55b6498ea66986786a58',
#        'location': {'address': '龙湖时代天街',
#         'cc': 'CN',
#         'city': '重庆市',
#         'country': '中国',
#         'crossStreet': '石油路',
#         'formattedAddress': ['龙湖时代天街 (石油路)', '重庆市', '重庆市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.53768187365713,
#           'lng': 106.50824792526366}],
#         'lat': 29.53768187365713,
#         'lng': 106.50824792526366,
#         'state': '重庆市'},
#        'name': '海派健身-healthPark',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5377366b498e8528a668f420-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5377366b498e8528a668f420',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.562015,
#           'lng': 106.575193}],
#         'lat': 29.562015,
#         'lng': 106.575193},
#        'name': 'Fitness Center @ Intercontinental',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51f5b095498e7d58728f7983-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '51f5b095498e7d58728f7983',
#        'location': {'address': 'DoubleTree By Hilton',
#         'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['DoubleTree By Hilton', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.581767,
#           'lng': 106.526684}],
#         'lat': 29.581767,
#         'lng': 106.526684},
#        'name': 'Hilton Fitness Center',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52720e6d498ee4b7624c8159-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '52720e6d498ee4b7624c8159',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.526841,
#           'lng': 106.566463}],
#         'lat': 29.526841,
#         'lng': 106.566463},
#        'name': 'Meridien fitness Centre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'flags': {'outsideRadius': True},
#       'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5cbc402a25ecca002c7e01da-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '5cbc402a25ecca002c7e01da',
#        'location': {'cc': 'CN',
#         'city': '重庆市',
#         'country': '中国',
#         'formattedAddress': ['重庆市', '重庆市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.703275490121577,
#           'lng': 107.39239811897278}],
#         'lat': 29.703275490121577,
#         'lng': 107.39239811897278,
#         'state': '重庆市'},
#        'name': 'Dream Fitness',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57b08f2e498eee0b0496174c-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_track_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d106941735',
#          'name': 'Track',
#          'pluralName': 'Tracks',
#          'primary': True,
#          'shortName': 'Track'}],
#        'id': '57b08f2e498eee0b0496174c',
#        'location': {'address': 'Huangyang Road',
#         'cc': 'CN',
#         'city': '重庆市',
#         'country': '中国',
#         'formattedAddress': ['Huangyang Road', '重庆市', '重庆市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.530191,
#           'lng': 106.524426}],
#         'lat': 29.530191,
#         'lng': 106.524426,
#         'state': '重庆市'},
#        'name': 'Running place',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Chongqing',
#   'headerLocation': 'Chongqing',
#   'headerLocationGranularity': 'city',
#   'query': 'gym fitness',
#   'suggestedBounds': {'ne': {'lat': 29.712556364627655,
#     'lng': 107.43660562865826},
#    'sw': {'lat': 29.508377125493926, 'lng': 106.4640404155782}},
#   'totalResults': 9}}

# %% [markdown]
# ##### Seeing from the JSON results of each search, we will extract info relates to the [name, address, location[latitude, longitude], summary], then we put the results into a pandas dataframe.

# %%
df_venues={}
for city in cities:
    venues = json_normalize(results_gym[city]['response']['groups'][0]['items'])
    df_venues[city] = venues[['venue.name', 'venue.location.address', \
                              'venue.location.lat', 'venue.location.lng']]
    df_venues[city].columns = ['Name', 'Address', 'Lat', 'Lng']

# %%
#Results table for Beijing, first 10 rows
df_venues[cities[0]].head(10)
# Out:
#                                            Name                     Address  \
# 0                          Pacific Century Club            2A Gongtibei Rd.
# 1                        B Active Sanlitun SOHO                         NaN
# 2                                  D-Space 东田运动          Futong West Street
# 3  CSI Bally Fitness (CSI Bally Fitness 中体倍力健身)  East Ave Apt B1 | 幸福三村3楼B1
# 4                         Young Fit Health Club     Shoucheng International
# 5                                     青鸟健身(百盛店)   西城区复兴门内大街101号百盛购物中心2号楼10楼
# 6                                Aloft Recharge       Tower 2, 25 Yuanda Rd
# 7                                  Keepland 华贸店                    华贸购物中心4层
# 8                                Oak Chateau じむ                         NaN
# 9                Keepland Fortune Plaza 财富购物中心店                   财富购物中心 2F
#
#          Lat         Lng
# 0  39.930683  116.452938
# 1  39.930395  116.447208
# 2  39.997054  116.474809
# 3  39.936832  116.445090
# 4  39.890490  116.462647
# 5  39.906550  116.355837
# 6  39.957065  116.273063
# 7  39.907962  116.475416
# 8  39.956521  116.453890
# 9  39.916225  116.453762

# %%
#Results table for Shanghai
df_venues[cities[1]]
# Out:
#                              Name  \
# 0                     Z&B Fitness
# 1                      The Clinic
# 2                    Pure Fitness
# 3              Z&B Fitness Studio
# 4                    Kerry Sports
# ..                            ...
# 95  Yoga @ Four Seasons, Shanghai
# 96                      Pure Yoga
# 97     Drishti Vinyasa Yoga Shala
# 98                          徐汇游泳馆
# 99                          浦东游泳馆
#
#                                               Address        Lat         Lng
# 0                                14/F 1219 Changle Rd  31.216626  121.437774
# 1   501, Building B, 98-118 Jiashan Rd | 徐汇区嘉善路98-...  31.213464  121.454507
# 2                         999 Huaihai M Rd | 淮海中路999号  31.217676  121.453586
# 3                         278 Shaanxi N Rd | 陕西北路278号  31.230207  121.449826
# 4                                       1388 Huamu Rd  31.215612  121.559629
# ..                                                ...        ...         ...
# 95                                     500, Weihai Lu  31.229149  121.457946
# 96         3/F-35 1266 Nanjing W Rd | 南京西路1266号恒隆广场3楼  31.229978  121.448635
# 97                                                NaN  31.225097  121.424711
# 98                                            枫林路329号  31.195170  121.452419
# 99                                          浦东南路3669号  31.190902  121.500847
#
# [100 rows x 4 columns]

# %%
#Results table for Chengdu
df_venues[cities[2]]
# Out:
#                                  Name  \
# 0     InterContinental Fitness Center
# 1                        St Regis Gym
# 2               传奇健身 (Legend Fitness)
# 3            舒适堡健身 (Physical Fitness)
# 4                     Pioneer Fitness
# 5                      Shangri-La Gym
# 6                   Fraser Suites Gym
# 7  Fitness Center at the Ritz Carlton
#
#                                              Address        Lat         Lng
# 0                             InterContinental Hotel  30.561565  104.070168
# 1                                                NaN  30.663660  104.071977
# 2                                                NaN  30.655025  104.112932
# 3                                            瑜伽中心IFS  30.657309  104.077639
# 4                                              优品道广场  30.666688  104.005027
# 5                                                NaN  30.645684  104.083268
# 6              111, Zhihui Street, Jinjiang District  30.654742  104.066789
# 7  23/F, The Ritz Carlton, 269 Shun cheng Avenue,...  30.666292  104.067639

# %%
#Results table for Chongqing
df_venues[cities[3]]
# Out:
#                                 Name                      Address        Lat  \
# 0            whytewoolf fitness club  No.55 Xiejiawan Main Street  29.517658
# 1                   Comjoy凯健国际健身 南坪店                    协信 星光时代广场  29.618965
# 2                          Hyatt Gym                          NaN  29.583370
# 3                    海派健身-healthPark                       龙湖时代天街  29.537682
# 4  Fitness Center @ Intercontinental                          NaN  29.562015
# 5              Hilton Fitness Center         DoubleTree By Hilton  29.581767
# 6            Meridien fitness Centre                          NaN  29.526841
# 7                      Dream Fitness                          NaN  29.703275
# 8                      Running place               Huangyang Road  29.530191
#
#           Lng
# 0  106.519060
# 1  106.509410
# 2  106.532234
# 3  106.508248
# 4  106.575193
# 5  106.526684
# 6  106.566463
# 7  107.392398
# 8  106.524426

# %% [markdown]
# ##### Display maps of local gym/fitness venues and calculate the total number of venues

# %%
maps_gyms={}
for city in cities:
    city_lat = np.mean([results_gym[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results_gym[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results_gym[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results_gym[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps_gyms[city] = folium.Map(location=[city_lat, city_lng], zoom_start=6)

    # add markers to map
    for lat, lng, label in zip(df_venues[city]['Lat'], df_venues[city]['Lng'], df_venues[city]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.7,
            parse_html=False).add_to(maps_gyms[city])  
    print(f"Total number of Gym/Fitness places in {city} = ", results_gym[city]['response']['totalResults'])
    print("Showing Top 100")
# Out:
# Total number of Gym/Fitness places in Beijing,Beijing =  49
# Showing Top 100
# Total number of Gym/Fitness places in Shanghai, Shanghai =  104
# Showing Top 100
# Total number of Gym/Fitness places in Chengdu, Sichuan =  8
# Showing Top 100
# Total number of Gym/Fitness places in Chongqing, Chongqing =  9
# Showing Top 100

# %%
#Display maps of local gym/fitness venues in Beijing
maps_gyms[cities[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Display maps of local gym/fitness venues in Shanghai
maps_gyms[cities[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Display maps of local gym/fitness venues in Chengdu
maps_gyms[cities[2]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Display maps of local gym/fitness venues in Chongqing
maps_gyms[cities[3]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###### Now lets explore the local sports shops

# %%
import requests
LIMIT = 10000
results_shops = {}
for city in cities:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        city,
        LIMIT,
        "4bf58dd8d48988d1f2941735") # Sports shops CATEGORY ID
    results_shops[city] = requests.get(url).json()

# %%
#Display the results in Beijing
#Same command can be used to display results for Shanghai, Chengdu, Chong
results_shops[cities[0]]
# Out:
# {'meta': {'code': 200, 'requestId': '5f23f186a12e764cfd3c7676'},
#  'response': {'geocode': {'cc': 'CN',
#    'center': {'lat': 39.9075, 'lng': 116.39723},
#    'displayString': 'Beijing, Beijing Shi, China',
#    'geometry': {'bounds': {'ne': {'lat': 41.05875499151405,
#       'lng': 117.49936797940963},
#      'sw': {'lat': 39.44236100189344, 'lng': 115.41642409091048}}},
#    'longId': '72057594039744606',
#    'slug': 'beijing',
#    'what': '',
#    'where': 'beijing beijing'},
#   'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b058794f964a5204d9b22e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4b058794f964a5204d9b22e3',
#        'location': {'address': '195 E 4th Ring M Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'Huagong Rd',
#         'formattedAddress': ['195 E 4th Ring M Rd (Huagong Rd)',
#          '北京市',
#          '北京市, 100000',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.884797491687394,
#           'lng': 116.48245959650174}],
#         'lat': 39.884797491687394,
#         'lng': 116.48245959650174,
#         'postalCode': '100000',
#         'state': '北京市'},
#        'name': 'Decathlon (迪卡侬)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5677b1c8498e8c399d9cd614-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '5677b1c8498e8c399d9cd614',
#        'location': {'address': '9 N 4th Ring Rd E',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'At B1/F of Siyuanqiao Mall',
#         'formattedAddress': ['9 N 4th Ring Rd E (At B1/F of Siyuanqiao Mall)',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.97737008509753,
#           'lng': 116.45459831922133}],
#         'lat': 39.97737008509753,
#         'lng': 116.45459831922133,
#         'state': '北京市'},
#        'name': 'Decathlon (迪卡侬)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b9b089af964a5205eed35e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4b9b089af964a5205eed35e3',
#        'location': {'address': '北京市朝阳区工体北路三里屯 Village 南侧',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['北京市朝阳区工体北路三里屯 Village 南侧',
#          '北京市',
#          '北京市, 100027',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.93252093502683,
#           'lng': 116.44838058920465}],
#         'lat': 39.93252093502683,
#         'lng': 116.44838058920465,
#         'postalCode': '100027',
#         'state': '北京市'},
#        'name': 'adidas',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd2bd5ba8b3a5931e73685f-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4bd2bd5ba8b3a5931e73685f',
#        'location': {'address': '19 Sanlitun Village Rd.',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'at GongTi Rd.',
#         'formattedAddress': ['19 Sanlitun Village Rd. (at GongTi Rd.)',
#          '北京市',
#          '北京市',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.93333823485628,
#           'lng': 116.4483013727682}],
#         'lat': 39.93333823485628,
#         'lng': 116.4483013727682,
#         'state': '北京市'},
#        'name': 'Nike',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bab68fdf964a5202da73ae3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4bab68fdf964a5202da73ae3',
#        'location': {'address': '66-1 Xiangbin Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['66-1 Xiangbin Rd', '北京市', '北京市, 100102', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.014956432871365,
#           'lng': 116.45788678090705}],
#         'lat': 40.014956432871365,
#         'lng': 116.45788678090705,
#         'postalCode': '100102',
#         'state': '北京市'},
#        'name': 'Decathlon 迪卡侬',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6d5305f964a52017712ce3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4b6d5305f964a52017712ce3',
#        'location': {'address': '186 Litang Rd.',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'at B1 of Longde Plaza',
#         'formattedAddress': ['186 Litang Rd. (at B1 of Longde Plaza)',
#          '北京市',
#          '北京市, 102218',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.05861071936462,
#           'lng': 116.40927532931028}],
#         'lat': 40.05861071936462,
#         'lng': 116.40927532931028,
#         'postalCode': '102218',
#         'state': '北京市'},
#        'name': 'Decathlon (迪卡侬)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58ef00b0f79faa04cee88416-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '58ef00b0f79faa04cee88416',
#        'location': {'address': 'Unit 251 - Level 2, 789 Nanjing West Road, Jingan',
#         'cc': 'CN',
#         'city': 'Shanghai',
#         'country': '中国',
#         'formattedAddress': ['Unit 251 - Level 2, 789 Nanjing West Road, Jingan',
#          'Shanghai',
#          'Kuala Lumpur, 200041',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.93717697821153,
#           'lng': 116.44828168383175}],
#         'lat': 39.93717697821153,
#         'lng': 116.44828168383175,
#         'postalCode': '200041',
#         'state': 'Kuala Lumpur'},
#        'name': 'lululemon',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5861fba13bd4ab627c3d8b4a-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '5861fba13bd4ab627c3d8b4a',
#        'location': {'address': '西直门北大街',
#         'cc': 'CN',
#         'city': '海淀区',
#         'country': '中国',
#         'crossStreet': '枫蓝国际地下',
#         'formattedAddress': ['西直门北大街 (枫蓝国际地下)', '海淀区', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.95200627395029,
#           'lng': 116.35009109635168}],
#         'lat': 39.95200627395029,
#         'lng': 116.35009109635168,
#         'state': '北京市'},
#        'name': 'Decathlon (迪卡侬)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-593b4bde9ec3995c0cee9df6-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '593b4bde9ec3995c0cee9df6',
#        'location': {'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.908175,
#           'lng': 116.271507}],
#         'lat': 39.908175,
#         'lng': 116.271507,
#         'state': '北京市'},
#        'name': 'Nike Basketball & Jordan Wukesong',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50f67183e4b079fc699d779c-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '50f67183e4b079fc699d779c',
#        'location': {'address': '王府井176号',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['王府井176号', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91118549789081,
#           'lng': 116.4050349944497}],
#         'lat': 39.91118549789081,
#         'lng': 116.4050349944497,
#         'state': '北京市'},
#        'name': '李宁 Li-Ning',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5043084ce4b0152f585a29a5-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '5043084ce4b0152f585a29a5',
#        'location': {'address': '99 Yuexiu Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'At 2/F of Tongxia Gongyuan 99',
#         'formattedAddress': ['99 Yuexiu Rd (At 2/F of Tongxia Gongyuan 99)',
#          '北京市',
#          '北京市, 100085',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.045487304091566,
#           'lng': 116.33099478025872}],
#         'lat': 40.045487304091566,
#         'lng': 116.33099478025872,
#         'postalCode': '100085',
#         'state': '北京市'},
#        'name': 'Decathlon (迪卡侬)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6bb32bf964a5200c162ce3-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4b6bb32bf964a5200c162ce3',
#        'location': {'address': 'The malls of Oriental Plaza',
#         'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['The malls of Oriental Plaza', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91276292086336,
#           'lng': 116.40550526751967}],
#         'lat': 39.91276292086336,
#         'lng': 116.40550526751967},
#        'name': 'Nike Beijing Store',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5194744c498e4703c63c41d4-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '5194744c498e4703c63c41d4',
#        'location': {'address': '丹棱路甲1号 1 Danling Road',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['丹棱路甲1号 1 Danling Road', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.978189716273356,
#           'lng': 116.30873327912333}],
#         'lat': 39.978189716273356,
#         'lng': 116.30873327912333,
#         'state': '北京市'},
#        'name': 'NIKE Basketball',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eb64fa7e5fa17fc87271972-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4eb64fa7e5fa17fc87271972',
#        'location': {'address': '138 Wangfujing Avenue',
#         'cc': 'CN',
#         'city': '东城区',
#         'country': '中国',
#         'formattedAddress': ['138 Wangfujing Avenue', '东城区', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.91265267292925,
#           'lng': 116.40525977784205}],
#         'lat': 39.91265267292925,
#         'lng': 116.40525977784205,
#         'state': '北京市'},
#        'name': 'Nike @APM',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4be50d11910020a1669cd214-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4be50d11910020a1669cd214',
#        'location': {'address': 'Sanlitun Village 1F',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['Sanlitun Village 1F', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.93334393628977,
#           'lng': 116.4484718502863}],
#         'lat': 39.93334393628977,
#         'lng': 116.4484718502863,
#         'state': '北京市'},
#        'name': 'Puma',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5688c5ac498edeff7c8e7f9f-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '5688c5ac498edeff7c8e7f9f',
#        'location': {'address': '59 Yuquan Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'crossStreet': 'Lugu Rd',
#         'formattedAddress': ['59 Yuquan Rd (Lugu Rd)', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.90268415809252,
#           'lng': 116.24814811399541}],
#         'lat': 39.90268415809252,
#         'lng': 116.24814811399541,
#         'state': '北京市'},
#        'name': 'Decathlon Yuquanlu Store (迪卡侬玉泉路店)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50210525e4b07d6577113e24-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '50210525e4b07d6577113e24',
#        'location': {'address': 'WB106, China World Shopping Mall, No 1 Jian Guo Men Wai av.',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['WB106, China World Shopping Mall, No 1 Jian Guo Men Wai av.',
#          '北京市',
#          '北京市, 100004',
#          '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.908908,
#           'lng': 116.45459}],
#         'lat': 39.908908,
#         'lng': 116.45459,
#         'postalCode': '100004',
#         'state': '北京市'},
#        'name': 'Y-3',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b99c078f964a520159035e3-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4b99c078f964a520159035e3',
#        'location': {'address': '马家堡西路 West Road of MaJiaPu',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['马家堡西路 West Road of MaJiaPu', '北京市', '北京市', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.832502869989014,
#           'lng': 116.36903285980225}],
#         'lat': 39.832502869989014,
#         'lng': 116.36903285980225,
#         'state': '北京市'},
#        'name': '迪卡侬 Decathlon',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b9dc3f8f964a520f1bc36e3-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4b9dc3f8f964a520f1bc36e3',
#        'location': {'address': '28 Zaojunmiao Rd',
#         'cc': 'CN',
#         'city': '北京市',
#         'country': '中国',
#         'formattedAddress': ['28 Zaojunmiao Rd', '北京市', '北京市, 100081', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.958127848622986,
#           'lng': 116.32929396115044}],
#         'lat': 39.958127848622986,
#         'lng': 116.32929396115044,
#         'postalCode': '100081',
#         'state': '北京市'},
#        'name': 'Faya Sports Factory Store (法雅体育折扣店)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55619b54498e9728a7d5ebdc-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '55619b54498e9728a7d5ebdc',
#        'location': {'address': '西红门荟聚',
#         'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['西红门荟聚, Дасин', '中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.784862016117934,
#           'lng': 116.31983834087438}],
#         'lat': 39.784862016117934,
#         'lng': 116.31983834087438},
#        'name': 'Decathlon (迪卡侬)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c311c14213c2d7f9e81335d-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'primary': True,
#          'shortName': 'Sporting Goods'}],
#        'id': '4c311c14213c2d7f9e81335d',
#        'location': {'cc': 'CN',
#         'country': '中国',
#         'formattedAddress': ['中国'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.96675685287147,
#           'lng': 116.37439329611547}],
#         'lat': 39.96675685287147,
#         'lng': 116.37439329611547},
#        'name': '三夫户外马甸店',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Beijing',
#   'headerLocation': 'Beijing',
#   'headerLocationGranularity': 'city',
#   'query': 'sporting goods',
#   'suggestedBounds': {'ne': {'lat': 40.072298154526955,
#     'lng': 116.49417517062706},
#    'sw': {'lat': 39.771174580955595, 'lng': 116.23643253987011}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 21}}

# %% [markdown]
# ###### Lets try to put the information from json file into pandas table
# ###### this time we use a function to do it, see below

# %%
#function to get category type
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
shops_beijing = results_shops[cities[0]]['response']['groups'][0]['items']
nearby_shops_beijing = json_normalize(shops_beijing)
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_shops_beijing = nearby_shops_beijing.loc[:, filtered_columns]
nearby_shops_beijing['venue.categories'] = nearby_shops_beijing.apply(get_category_type, axis=1)
nearby_shops_beijing.columns = [col.split('.')[-1] for col in nearby_shops_beijing.columns]
nearby_shops_beijing
# Out:
#                                    name           categories        lat  \
# 0                       Decathlon (迪卡侬)  Sporting Goods Shop  39.884797
# 1                       Decathlon (迪卡侬)  Sporting Goods Shop  39.977370
# 2                                adidas  Sporting Goods Shop  39.932521
# 3                                  Nike  Sporting Goods Shop  39.933338
# 4                         Decathlon 迪卡侬  Sporting Goods Shop  40.014956
# 5                       Decathlon (迪卡侬)  Sporting Goods Shop  40.058611
# 6                             lululemon  Sporting Goods Shop  39.937177
# 7                       Decathlon (迪卡侬)  Sporting Goods Shop  39.952006
# 8     Nike Basketball & Jordan Wukesong  Sporting Goods Shop  39.908175
# 9                            李宁 Li-Ning  Sporting Goods Shop  39.911185
# 10                      Decathlon (迪卡侬)  Sporting Goods Shop  40.045487
# 11                   Nike Beijing Store  Sporting Goods Shop  39.912763
# 12                      NIKE Basketball  Sporting Goods Shop  39.978190
# 13                            Nike @APM  Sporting Goods Shop  39.912653
# 14                                 Puma  Sporting Goods Shop  39.933344
# 15   Decathlon Yuquanlu Store (迪卡侬玉泉路店)  Sporting Goods Shop  39.902684
# 16                                  Y-3  Sporting Goods Shop  39.908908
# 17                        迪卡侬 Decathlon  Sporting Goods Shop  39.832503
# 18  Faya Sports Factory Store (法雅体育折扣店)  Sporting Goods Shop  39.958128
# 19                      Decathlon (迪卡侬)  Sporting Goods Shop  39.784862
# 20                              三夫户外马甸店  Sporting Goods Shop  39.966757
#
#            lng
# 0   116.482460
# 1   116.454598
# 2   116.448381
# 3   116.448301
# 4   116.457887
# 5   116.409275
# 6   116.448282
# 7   116.350091
# 8   116.271507
# 9   116.405035
# 10  116.330995
# 11  116.405505
# 12  116.308733
# 13  116.405260
# 14  116.448472
# 15  116.248148
# 16  116.454590
# 17  116.369033
# 18  116.329294
# 19  116.319838
# 20  116.374393

# %%
shops_shanghai = results_shops[cities[1]]['response']['groups'][0]['items']
nearby_shops_shanghai = json_normalize(shops_shanghai)
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_shops_shanghai = nearby_shops_shanghai.loc[:, filtered_columns]
nearby_shops_shanghai['venue.categories'] = nearby_shops_shanghai.apply(get_category_type, axis=1)
nearby_shops_shanghai.columns = [col.split('.')[-1] for col in nearby_shops_shanghai.columns]
nearby_shops_shanghai
# Out:
#                                     name           categories        lat  \
# 0                            X158 - Nike  Sporting Goods Shop  31.219140
# 1                                   Nike  Sporting Goods Shop  31.221152
# 2                              Décathlon  Sporting Goods Shop  31.206884
# 3                        Décathlon (迪卡侬)  Sporting Goods Shop  31.210899
# 4                       adidas Originals  Sporting Goods Shop  31.231926
# 5   Nike | House of Innovation (Nike旗舰店)  Sporting Goods Shop  31.236050
# 6                        Décathlon (迪卡侬)  Sporting Goods Shop  31.239798
# 7                        Décathlon (迪卡侬)  Sporting Goods Shop  31.170590
# 8                    Nike Employee Store  Sporting Goods Shop  31.234174
# 9                        Décathlon (迪卡侬)  Sporting Goods Shop  31.148604
# 10                       Décathlon (迪卡侬)  Sporting Goods Shop  31.243514
# 11                       Décathlon (迪卡侬)  Sporting Goods Shop  31.298207
# 12                       Décathlon (迪卡侬)  Sporting Goods Shop  31.094751
# 13                   Adidas Brand Centre  Sporting Goods Shop  31.221388
# 14                       Décathlon (迪卡侬)  Sporting Goods Shop  31.307338
# 15                            Nike Store  Sporting Goods Shop  31.237814
# 16            Nike Campus Employee Store  Sporting Goods Shop  31.318908
# 17                          Nike Running  Sporting Goods Shop  31.228610
# 18                    Jordan 139 NANDONG  Sporting Goods Shop  31.240070
# 19                       Décathlon (迪卡侬)  Sporting Goods Shop  31.245664
# 20                               Li-Ning  Sporting Goods Shop  31.237314
# 21                                  Nike  Sporting Goods Shop  31.220082
# 22                    TopSports Ⅱ (滔搏运动)  Sporting Goods Shop  31.184833
# 23                           Sports City  Sporting Goods Shop  31.196473
# 24                                adidas  Sporting Goods Shop  31.227360
# 25                               H3 Club  Sporting Goods Shop  31.166054
# 26                    Nike Factory Store  Sporting Goods Shop  31.212623
# 27                    Technogym Shanghai  Sporting Goods Shop  31.230211
# 28               Adidas NJE 800 Shanghai  Sporting Goods Shop  31.236986
# 29                              Converse  Sporting Goods Shop  31.239176
# 30                       Décathlon (迪卡侬)  Sporting Goods Shop  31.166199
# 31                       Décathlon (迪卡侬)  Sporting Goods Shop  31.180861
# 32                       Nike Basketball  Sporting Goods Shop  31.239267
# 33                           三夫户外店 SANFO  Sporting Goods Shop  31.184760
# 34                          Adidas Women  Sporting Goods Shop  31.218231
# 35                                Adidas  Sporting Goods Shop  31.159474
# 36                     Nike Kicks Lounge  Sporting Goods Shop  31.218139
# 37                            Xebio (赛标)  Sporting Goods Shop  31.229806
# 38                                adidas  Sporting Goods Shop  31.239592
# 39                           Nike Outlet  Sporting Goods Shop  31.159050
# 40                       Décathlon (迪卡侬)  Sporting Goods Shop  31.263187
# 41                          Under Armour  Sporting Goods Shop  31.220999
# 42                    Under Armour (安德玛)  Sporting Goods Shop  31.196547
#
#            lng
# 0   121.449437
# 1   121.460401
# 2   121.556237
# 3   121.365779
# 4   121.454764
# 5   121.470383
# 6   121.410626
# 7   121.279336
# 8   121.449185
# 9   121.401420
# 10  121.577973
# 11  121.443353
# 12  121.382249
# 13  121.460833
# 14  121.509062
# 15  121.476233
# 16  121.503541
# 17  121.553940
# 18  121.482157
# 19  121.377455
# 20  121.474794
# 21  121.411615
# 22  121.437234
# 23  121.432870
# 24  121.442258
# 25  121.335932
# 26  121.398881
# 27  121.437067
# 28  121.470830
# 29  121.495630
# 30  121.333721
# 31  121.489226
# 32  121.497110
# 33  121.439087
# 34  121.453503
# 35  121.223508
# 36  121.453815
# 37  121.514254
# 38  121.497149
# 39  121.223610
# 40  121.507714
# 41  121.460022
# 42  121.432814

# %%
shops_chengdu = results_shops[cities[2]]['response']['groups'][0]['items']
nearby_shops_chengdu = json_normalize(shops_chengdu)
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_shops_chengdu = nearby_shops_chengdu.loc[:, filtered_columns]
nearby_shops_chengdu['venue.categories'] = nearby_shops_chengdu.apply(get_category_type, axis=1)
nearby_shops_chengdu.columns = [col.split('.')[-1] for col in nearby_shops_chengdu.columns]
nearby_shops_chengdu
# Out:
#                            name           categories        lat         lng
# 0                 Décathlon 迪卡侬  Sporting Goods Shop  30.601965  104.061481
# 1                        Jordan  Sporting Goods Shop  30.655846  104.077680
# 2                     Decathlon  Sporting Goods Shop  30.721240  104.033790
# 3               阿迪达斯(优客城市广场折扣店)  Sporting Goods Shop  30.667492  104.099213
# 4               Decathlon (迪卡侬)  Sporting Goods Shop  30.649811  104.114910
# 5                 adidas (春熙路店)  Sporting Goods Shop  30.654301  104.079187
# 6                           迪卡侬  Sporting Goods Shop  30.721633  104.033722
# 7         劲浪体育 High Wave Sports  Sporting Goods Shop  30.659123  104.071255
# 8                adidas (金开百货店)  Sporting Goods Shop  30.655967  104.075620
# 9   Chengdu Houzimen Nike Store  Sporting Goods Shop  30.664022  104.063914
# 10                   nike store  Sporting Goods Shop  30.657296  104.074297
# 11                       adidas  Sporting Goods Shop  30.657032  104.082603
# 12             阿迪达斯三叶草(龙湖西宸天街店)  Sporting Goods Shop  30.697324  104.031476
# 13                 阿迪达斯(蜗牛郡折扣店)  Sporting Goods Shop  30.782367  103.943912
# 14                 Under Armour  Sporting Goods Shop  30.656420  104.082278
# 15              阿迪达斯(希望奥特莱斯折扣店)  Sporting Goods Shop  30.376602  103.838392

# %%
shops_chongqing = results_shops[cities[3]]['response']['groups'][0]['items']
nearby_shops_chongqing = json_normalize(shops_chongqing)
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_shops_chongqing = nearby_shops_chongqing.loc[:, filtered_columns]
nearby_shops_chongqing['venue.categories'] = nearby_shops_chongqing.apply(get_category_type, axis=1)
nearby_shops_chongqing.columns = [col.split('.')[-1] for col in nearby_shops_chongqing.columns]
nearby_shops_chongqing
# Out:
#                  name           categories        lat         lng
# 0           迪卡侬（冉家坝店）  Sporting Goods Shop  29.582354  106.489680
# 1  阿迪达斯三叶草(东原新新Park店)  Sporting Goods Shop  29.570695  106.497085
# 2       阿迪达斯(八一广场旗舰店)  Sporting Goods Shop  29.555358  106.576354
# 3              adidas  Sporting Goods Shop  29.557120  106.580138
# 4       迪卡侬 Decathlon  Sporting Goods Shop  29.574167  106.568758
# 5                劲浪体育  Sporting Goods Shop  29.576361  106.531259
# 6    阿迪达斯(百联南岸上海城折扣店)  Sporting Goods Shop  29.528895  106.560827
# 7              Adidas  Sporting Goods Shop  29.575000  106.571023
# 8     Decathlon (迪卡侬)  Sporting Goods Shop  29.530005  106.507960

# %%
df_shops={}
for city in cities:
    shops = json_normalize(results_shops[city]['response']['groups'][0]['items'])
    df_shops[city] = shops[['venue.name', 'venue.location.address', \
                              'venue.location.lat', 'venue.location.lng']]
    df_shops[city].columns = ['Name', 'Address', 'Lat', 'Lng']

# %%
maps_shops={}

for city in cities:
    city_lat = np.mean([results_shops[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results_shops[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results_shops[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results_shops[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    
    maps_shops[city] = folium.Map(location=[city_lat, city_lng], zoom_start=12)

    # add markers to map
    for lat, lng, label in zip(df_shops[city]['Lat'], df_shops[city]['Lng'], df_shops[city]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.7,
            parse_html=False).add_to(maps_shops[city]) 
        
    print(f"Total number of sports shop places in {city} = ", results_shops[city]['response']['totalResults'])
    print("Showing Top 100")
# Out:
# Total number of sports shop places in Beijing,Beijing =  21
# Showing Top 100
# Total number of sports shop places in Shanghai, Shanghai =  43
# Showing Top 100
# Total number of sports shop places in Chengdu, Sichuan =  16
# Showing Top 100
# Total number of sports shop places in Chongqing, Chongqing =  9
# Showing Top 100

# %%
#map display sports shops in Shanghai
maps_shops[cities[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#map display sports shops in Shanghai
maps_shops[cities[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#display gyms in Beijing
maps_gyms[cities[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#display sports shops in Shanghai
maps_gyms[cities[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
no_of_gyms_Beijing =  results_gym[cities[0]]['response']['totalResults']
no_of_shops_Beijing = results_shops[cities[0]]['response']['totalResults']
gym_shops_ratio_Beijing = no_of_gyms_Beijing/no_of_shops_Beijing
print(gym_shops_ratio_Beijing)
# Out:
# 2.3333333333333335

# %%
no_of_gyms_Shanghai =  results_gym[cities[1]]['response']['totalResults']
no_of_shops_Shanghai = results_shops[cities[1]]['response']['totalResults']
gym_shops_ratio_Shanghai = no_of_gyms_Shanghai/no_of_shops_Shanghai
print(gym_shops_ratio_Shanghai)
# Out:
# 2.4186046511627906

# %%
for city in cities:
    city_lat = np.mean([results_shops[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results_shops[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results_shops[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results_shops[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    

    map_Shanghai = maps_gyms[cities[1]]

    for lat, lng, label in zip(df_shops[city]['Lat'], df_shops[city]['Lng'], df_shops[city]['Name']):
            label = folium.Popup(label, parse_html=True)
            folium.CircleMarker(
                [lat, lng],
                radius=5,
                popup=label,
                color='red',
                fill=True,
                fill_color='red',
                fill_opacity=0.7,
                parse_html=False).add_to(map_Shanghai) 

            
    for lat, lng, label in zip(df_shops[city]['Lat'], df_shops[city]['Lng'], df_shops[city]['Name']):
            label = folium.Popup(label, parse_html=True)
            folium.Circle(
                [31.229978, 121.448635],
                radius=1000,
                popup=label,
                color='#FF7F0F',
                fill=False).add_to(map_Shanghai)
map_Shanghai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
